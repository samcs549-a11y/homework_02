# %% [markdown]
# # Homework02
#
# Some exercises with `CSV` files, `Python` lists, `for` loops and `if` statements.
#
# ## Goals
#
# - Gain experience with Python, a popular scripting language used for ML/AI projects and research
# - Get familiar with Python's notation for lists and objects
# - Experiment with Python's unique functionalities for processing lists and objects
# - Learn to load and process `CSV` files using Python

# %% [markdown]
# ## More Wine Dataset
#
# Load the wine dataset like we did in class and answer the following questions.
#
# Don't worry about getting all of them at first.
#
# If you get stuck on `Python` syntax errors, just submit a description of the logic that you were trying to implement. Like, which pattern from the class notebook were you following ? How do you initialize the results variable ? Which conditions are you checking in the loop ?
#
# ## Questions
#
# - What's the average rating for California wines ?
# - What's the most expensive wine from Spain ?
# - Where's the worse wine in the US from ?
# - Which country between spain/us/france has highest average price ?
# - Which country between spain/us/france has highest average quality points ?
# - Are the best wines also the most expensive ?
#
# The last question is a bit hard to answer definitively with just loops, but what we can do is come up with a couple of searches to find counterexamples. For example, are there top rated wines (say, more than $92$ points) that are also cheap (less than $\$20$) ?

# %% [markdown]
# ## Getting Started
#
# The following cells download the file, import the `csv` library and load the `wines.csv` file into a variable called `wine_data`.

# %%
# !wget -q https://raw.githubusercontent.com/PSAM-5005-2026S-A/5005-utils/refs/heads/main/datasets/csv/wines.csv -P ./data

# %%
# pre-built code that helps us with specific tasks
import csv

# %%
# TODO: open csv, read csv, turn into list for processing with for loops

csvfile = open("./data/wines.csv")
csvreader = csv.reader(csvfile)
wine_data = list(csvreader)

display(wine_data)
# Out:
# [['ID',
#   'country',
#   'designation',
#   'points',
#   'price',
#   'province',
#   'region',
#   'variety',
#   'winery'],
#  ['0',
#   'US',
#   "Martha's Vineyard",
#   '96',
#   '235.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Heitz'],
#  ['1',
#   'Spain',
#   'Carodorum Selección Especial Reserva',
#   '96',
#   '110.0',
#   'Northern Spain',
#   'Toro',
#   'Tinta de Toro',
#   'Bodega Carmen Rodríguez'],
#  ['2',
#   'US',
#   'Special Selected Late Harvest',
#   '96',
#   '90.0',
#   'California',
#   'Knights Valley',
#   'Sauvignon Blanc',
#   'Macauley'],
#  ['3',
#   'US',
#   'Reserve',
#   '96',
#   '65.0',
#   'Oregon',
#   'Willamette Valley',
#   'Pinot Noir',
#   'Ponzi'],
#  ['4',
#   'France',
#   'La Brûlade',
#   '95',
#   '66.0',
#   'Provence',
#   'Bandol',
#   'Provence red blend',
#   'Domaine de la Bégude'],
#  ['5',
#   'Spain',
#   'Numanthia',
#   '95',
#   '73.0',
#   'Northern Spain',
#   'Toro',
#   'Tinta de Toro',
#   'Numanthia'],
#  ['6',
#   'Spain',
#   'San Román',
#   '95',
#   '65.0',
#   'Northern Spain',
#   'Toro',
#   'Tinta de Toro',
#   'Maurodos'],
#  ['7',
#   'Spain',
#   'Carodorum Único Crianza',
#   '95',
#   '110.0',
#   'Northern Spain',
#   'Toro',
#   'Tinta de Toro',
#   'Bodega Carmen Rodríguez'],
#  ['8',
#   'US',
#   'Silice',
#   '95',
#   '65.0',
#   'Oregon',
#   'Chehalem Mountains',
#   'Pinot Noir',
#   'Bergström'],
#  ['9',
#   'US',
#   "Gap's Crown Vineyard",
#   '95',
#   '60.0',
#   'California',
#   'Sonoma Coast',
#   'Pinot Noir',
#   'Blue Farm'],
#  ['10',
#   'Italy',
#   'Ronco della Chiesa',
#   '95',
#   '80.0',
#   'Northeastern Italy',
#   'Collio',
#   'Friulano',
#   'Borgo del Tiglio'],
#  ['11',
#   'US',
#   'Estate Vineyard Wadensvil Block',
#   '95',
#   '48.0',
#   'Oregon',
#   'Ribbon Ridge',
#   'Pinot Noir',
#   'Patricia Green Cellars'],
#  ['12',
#   'US',
#   'Weber Vineyard',
#   '95',
#   '48.0',
#   'Oregon',
#   'Dundee Hills',
#   'Pinot Noir',
#   'Patricia Green Cellars'],
#  ['13',
#   'France',
#   'Château Montus Prestige',
#   '95',
#   '90.0',
#   'Southwest France',
#   'Madiran',
#   'Tannat',
#   'Vignobles Brumont'],
#  ['14',
#   'US',
#   'Grace Vineyard',
#   '95',
#   '185.0',
#   'Oregon',
#   'Dundee Hills',
#   'Pinot Noir',
#   'Domaine Serene'],
#  ['15',
#   'US',
#   'Sigrid',
#   '95',
#   '90.0',
#   'Oregon',
#   'Willamette Valley',
#   'Chardonnay',
#   'Bergström'],
#  ['16',
#   'US',
#   'Rainin Vineyard',
#   '95',
#   '325.0',
#   'California',
#   'Diamond Mountain District',
#   'Cabernet Sauvignon',
#   'Hall'],
#  ['17',
#   'Spain',
#   '6 Años Reserva Premium',
#   '95',
#   '80.0',
#   'Northern Spain',
#   'Ribera del Duero',
#   'Tempranillo',
#   'Valduero'],
#  ['18',
#   'France',
#   'Le Pigeonnier',
#   '95',
#   '290.0',
#   'Southwest France',
#   'Cahors',
#   'Malbec',
#   'Château Lagrézette'],
#  ['19',
#   'US',
#   "Gap's Crown Vineyard",
#   '95',
#   '75.0',
#   'California',
#   'Sonoma Coast',
#   'Pinot Noir',
#   'Gary Farrell'],
#  ['20',
#   'US',
#   'Grignolino',
#   '95',
#   '24.0',
#   'California',
#   'Napa Valley',
#   'Rosé',
#   'Heitz'],
#  ['21',
#   'Spain',
#   'Prado Enea Gran Reserva',
#   '95',
#   '79.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo Blend',
#   'Muga'],
#  ['22',
#   'Spain',
#   'Termanthia',
#   '95',
#   '220.0',
#   'Northern Spain',
#   'Toro',
#   'Tinta de Toro',
#   'Numanthia'],
#  ['23',
#   'US',
#   'Giallo Solare',
#   '95',
#   '60.0',
#   'California',
#   'Edna Valley',
#   'Chardonnay',
#   'Center of Effort'],
#  ['24',
#   'US',
#   'R-Bar-R Ranch',
#   '95',
#   '45.0',
#   'California',
#   'Santa Cruz Mountains',
#   'Pinot Noir',
#   'Comartin'],
#  ['26',
#   'US',
#   'Shea Vineyard',
#   '94',
#   '62.0',
#   'Oregon',
#   'Willamette Valley',
#   'Pinot Noir',
#   'Bergström'],
#  ['27',
#   'US',
#   'Abetina',
#   '94',
#   '105.0',
#   'Oregon',
#   'Willamette Valley',
#   'Pinot Noir',
#   'Ponzi'],
#  ['28',
#   'US',
#   "Garys' Vineyard",
#   '94',
#   '60.0',
#   'California',
#   'Santa Lucia Highlands',
#   'Pinot Noir',
#   'Roar'],
#  ['29',
#   'US',
#   'The Funk Estate',
#   '94',
#   '60.0',
#   'Washington',
#   'Walla Walla Valley (WA)',
#   'Syrah',
#   'Saviah'],
#  ['31',
#   'US',
#   'Babushka',
#   '90',
#   '37.0',
#   'California',
#   'Russian River Valley',
#   'Chardonnay',
#   'Zepaltas'],
#  ['33',
#   'France',
#   'Nonpareil Trésor Rosé Brut',
#   '90',
#   '22.0',
#   'France Other',
#   'Vin Mousseux',
#   'Sparkling Blend',
#   'Bouvet-Ladubay'],
#  ['34',
#   'US',
#   'Conner Lee Vineyard',
#   '90',
#   '42.0',
#   'Washington',
#   'Columbia Valley (WA)',
#   'Chardonnay',
#   'Buty'],
#  ['35',
#   'Italy',
#   'Riserva',
#   '90',
#   '135.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Carillon'],
#  ['39',
#   'Italy',
#   'Riserva',
#   '90',
#   '29.0',
#   'Tuscany',
#   'Chianti Classico',
#   'Red Blend',
#   'Castello di Monterinaldi'],
#  ['40',
#   'Spain',
#   'Amandi',
#   '90',
#   '17.0',
#   'Galicia',
#   'Ribeira Sacra',
#   'Mencía',
#   'Don Bernardino'],
#  ['41',
#   'Spain',
#   'Alfonso Oloroso Seco',
#   '90',
#   '26.0',
#   'Andalucia',
#   'Jerez',
#   'Palomino',
#   'González Byass'],
#  ['43',
#   'Italy',
#   'Riserva',
#   '90',
#   '39.0',
#   'Tuscany',
#   'Chianti Classico',
#   'Red Blend',
#   'Rignana'],
#  ['44',
#   'France',
#   'Coteaux',
#   '90',
#   '69.0',
#   'Rhône Valley',
#   'Cornas',
#   'Syrah',
#   'Tardieu-Laurent'],
#  ['45',
#   'Italy',
#   'Vigneto Odoardo Beccari Riserva',
#   '90',
#   '30.0',
#   'Tuscany',
#   'Chianti Classico',
#   'Red Blend',
#   'Vignavecchia'],
#  ['46',
#   'Italy',
#   'Poggio alle Mura',
#   '90',
#   '90.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Banfi'],
#  ['47',
#   'US',
#   'Estate Grown',
#   '90',
#   '60.0',
#   'California',
#   'Mount Veeder',
#   'Cabernet Sauvignon',
#   'Brandlin'],
#  ['50',
#   'Italy',
#   'Riserva',
#   '90',
#   '100.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Capanne Ricci'],
#  ['52',
#   'France',
#   'Les 7 Hommes',
#   '90',
#   '42.0',
#   'Loire Valley',
#   'Sancerre',
#   'Sauvignon Blanc',
#   'Cherrier Frères'],
#  ['53',
#   'France',
#   "L'Inédit",
#   '90',
#   '28.0',
#   'Loire Valley',
#   'Coteaux du Giennois',
#   'Pinot Noir',
#   'Clement et Florian Berthier'],
#  ['55',
#   'US',
#   'Four Flags',
#   '90',
#   '69.0',
#   'Washington',
#   'Red Mountain',
#   'Cabernet Sauvignon',
#   'DeLille'],
#  ['57',
#   'US',
#   'Reserve',
#   '90',
#   '25.0',
#   'New York',
#   'Finger Lakes',
#   'Riesling',
#   'Dr. Konstantin Frank'],
#  ['58',
#   'US',
#   'Final Final',
#   '90',
#   '30.0',
#   'Washington',
#   'Columbia Valley (WA)',
#   'Cabernet Sauvignon-Syrah',
#   'Efeste'],
#  ['59',
#   'Italy',
#   'Poggio Bestiale',
#   '90',
#   '60.0',
#   'Tuscany',
#   'Maremma Toscana',
#   'Red Blend',
#   'Fattoria di Magliano'],
#  ['60',
#   'Argentina',
#   "The Apple Doesn't Fall Far From The Tree",
#   '91',
#   '30.0',
#   'Mendoza Province',
#   'Mendoza',
#   'Malbec',
#   'Matias Riccitelli'],
#  ['62',
#   'Argentina',
#   'Alegoría Gran Reserva',
#   '91',
#   '25.0',
#   'Mendoza Province',
#   'Mendoza',
#   'Malbec',
#   'Navarro Correas'],
#  ['63',
#   'France',
#   "L'Homme Mort Premier Cru",
#   '91',
#   '45.0',
#   'Burgundy',
#   'Chablis',
#   'Chardonnay',
#   'Domaine Chenevières'],
#  ['65',
#   'US',
#   'Estate Select',
#   '91',
#   '36.0',
#   'California',
#   'Santa Clara Valley',
#   'Syrah',
#   'Jason-Stephens'],
#  ['66',
#   'France',
#   'Fourchaume Premier Cru',
#   '91',
#   '38.0',
#   'Burgundy',
#   'Chablis',
#   'Chardonnay',
#   'Louis Max'],
#  ['67',
#   'US',
#   'Animo',
#   '91',
#   '85.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Michael Mondavi Family Estate'],
#  ['68',
#   'US',
#   'Schindler Vineyard',
#   '91',
#   '50.0',
#   'Oregon',
#   'Eola-Amity Hills',
#   'Pinot Noir',
#   'Panther Creek'],
#  ['69',
#   'US',
#   'Barrel Select',
#   '91',
#   '60.0',
#   'California',
#   'Rutherford',
#   'Cabernet Sauvignon',
#   'Provenance Vineyards'],
#  ['70',
#   'US',
#   'District Collection',
#   '91',
#   '85.0',
#   'California',
#   'St. Helena',
#   'Cabernet Sauvignon',
#   'Raymond'],
#  ['75',
#   'US',
#   'Premier Cuvée',
#   '91',
#   '54.0',
#   'Oregon',
#   'Willamette Valley',
#   'Pinot Noir',
#   'Archery Summit'],
#  ['76',
#   'France',
#   "Le Nombre d'Or Brut Nature",
#   '91',
#   '85.0',
#   'Champagne',
#   'Champagne',
#   'Chardonnay',
#   'Aubry'],
#  ['77',
#   'US',
#   'Juliana Vineyard',
#   '91',
#   '38.0',
#   'California',
#   'Napa Valley',
#   'Sauvignon Blanc',
#   'B Cellars'],
#  ['79',
#   'Italy',
#   'Boscato',
#   '91',
#   '75.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Bel Colle'],
#  ['80',
#   'US',
#   'Aeolian',
#   '91',
#   '42.0',
#   'Oregon',
#   'Eola-Amity Hills',
#   'Pinot Noir',
#   'Bethel Heights'],
#  ['83',
#   'Italy',
#   "del Comune di Serralunga d'Alba",
#   '91',
#   '59.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Cascina Cucco'],
#  ['84',
#   'Italy',
#   'Bricco Luciani',
#   '91',
#   '85.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Cascina del Monastero'],
#  ['85',
#   'Italy',
#   'Bricco Gattera',
#   '91',
#   '80.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Cordero di Montezemolo'],
#  ['86',
#   'France',
#   'Montmains Premier Cru',
#   '91',
#   '45.0',
#   'Burgundy',
#   'Chablis',
#   'Chardonnay',
#   'Domaine Gérard Duplessis'],
#  ['88',
#   'US',
#   'Bacigalupi Vineyard',
#   '91',
#   '65.0',
#   'California',
#   'Russian River Valley',
#   'Pinot Noir',
#   'Eleven Eleven'],
#  ['89',
#   'US',
#   'Magnificat',
#   '91',
#   '50.0',
#   'California',
#   'Napa Valley',
#   'Meritage',
#   'Franciscan'],
#  ['92',
#   'Italy',
#   'Nature',
#   '86',
#   '22.0',
#   'Veneto',
#   'Prosecco',
#   'Glera',
#   'De Stefani'],
#  ['93',
#   'US',
#   'Small Lot Blend',
#   '86',
#   '13.0',
#   'California',
#   'Mendocino County',
#   'Chardonnay',
#   'Parducci'],
#  ['95',
#   'France',
#   'Château Beauvillain-Monpezat',
#   '86',
#   '14.0',
#   'Southwest France',
#   'Cahors',
#   'Malbec-Merlot',
#   'Rigal'],
#  ['98',
#   'France',
#   'Pigmentum',
#   '86',
#   '15.0',
#   'Southwest France',
#   'Buzet',
#   'Merlot-Malbec',
#   'Georges Vigouroux'],
#  ['99',
#   'France',
#   'Pigmentum',
#   '86',
#   '10.0',
#   'Southwest France',
#   'Côtes de Gascogne',
#   'Ugni Blanc-Colombard',
#   'Georges Vigouroux'],
#  ['101',
#   'US',
#   'Stephanie',
#   '86',
#   '50.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Hestan'],
#  ['103',
#   'US',
#   "Bella's Blend",
#   '86',
#   '48.0',
#   'California',
#   'Knights Valley',
#   'Cabernet Sauvignon-Cabernet Franc',
#   'Ehret'],
#  ['104',
#   'US',
#   'Tears of Dew Late Harvest',
#   '86',
#   '20.0',
#   'California',
#   'Paso Robles',
#   'Moscato',
#   'EOS'],
#  ['105',
#   'US',
#   'Tudor Hills Vineyard',
#   '86',
#   '17.0',
#   'Washington',
#   'Yakima Valley',
#   'Pinot Grigio',
#   'Martinez & Martinez'],
#  ['109',
#   'US',
#   'Homestead Block',
#   '86',
#   '45.0',
#   'California',
#   'Napa Valley',
#   'Chardonnay',
#   'Kuleto Estate'],
#  ['111',
#   'Argentina',
#   'Terroir Único Pinot Noir',
#   '86',
#   '12.0',
#   'Mendoza Province',
#   'Tupungato',
#   'Rosé',
#   'Zorzal'],
#  ['112',
#   'US',
#   'Limited Release Cold Springs Vineyard',
#   '86',
#   '125.0',
#   'California',
#   'Howell Mountain',
#   'Cabernet Sauvignon',
#   'Charles Krug'],
#  ['113',
#   'US',
#   'Castle Hill Vineyard',
#   '86',
#   '25.0',
#   'New York',
#   'Hudson River Region',
#   'Riesling',
#   'Millbrook'],
#  ['115',
#   'Argentina',
#   'Reserva',
#   '86',
#   '15.0',
#   'Mendoza Province',
#   'Valle de Uco',
#   'Malbec',
#   'Viñalba'],
#  ['120',
#   'US',
#   'The Flyer',
#   '91',
#   '59.0',
#   'California',
#   'Russian River Valley',
#   'Pinot Noir',
#   'MacPhail'],
#  ['121',
#   'US',
#   'Charles Vineyard Clone 05',
#   '91',
#   '49.0',
#   'California',
#   'Anderson Valley',
#   'Pinot Noir',
#   'Foursight'],
#  ['122',
#   'US',
#   'Solomon Hills Vineyard Rosé',
#   '91',
#   '42.0',
#   'California',
#   'Santa Maria Valley',
#   'Sparkling Blend',
#   'Goat Bubbles'],
#  ['123',
#   'US',
#   'Paris Tasting Commemorative',
#   '91',
#   '93.0',
#   'California',
#   'Napa Valley',
#   'Chardonnay',
#   'Grgich Hills'],
#  ['124',
#   'US',
#   "Methode a l'Ancienne",
#   '91',
#   '32.0',
#   'California',
#   'Anderson Valley',
#   'Pinot Noir',
#   'Navarro'],
#  ['126',
#   'US',
#   'Grand Wren',
#   '90',
#   '100.0',
#   'California',
#   'Amador County',
#   'Zinfandel',
#   'Renwood'],
#  ['127',
#   'US',
#   'Central Park West Vineyard',
#   '90',
#   '50.0',
#   'California',
#   'St. Helena',
#   'Cabernet Sauvignon',
#   'Trinchero'],
#  ['128',
#   'Spain',
#   'Arnegui Reserva',
#   '90',
#   '22.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo',
#   'Pagos del Rey'],
#  ['129',
#   'Italy',
#   'Chianta Bianco',
#   '90',
#   '45.0',
#   'Sicily & Sardinia',
#   'Etna',
#   'White Blend',
#   'Biondi'],
#  ['132',
#   'US',
#   'Cooper Ranch',
#   '90',
#   '26.0',
#   'California',
#   'Amador County',
#   'Barbera',
#   'Andis'],
#  ['134',
#   'US',
#   'Longwood',
#   '90',
#   '30.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Beaucanon'],
#  ['135',
#   'US',
#   'Estate',
#   '90',
#   '42.0',
#   'California',
#   'Adelaida District',
#   'Grenache',
#   'Brecon Estate'],
#  ['136',
#   'US',
#   'Mustang Springs',
#   '90',
#   '38.0',
#   'California',
#   'Adelaida District',
#   'Zinfandel',
#   'Peachy Canyon'],
#  ['137',
#   'US',
#   'SMC',
#   '90',
#   '48.0',
#   'California',
#   'California',
#   'Rhône-style Red Blend',
#   'Three'],
#  ['138',
#   'Spain',
#   'Crianza',
#   '90',
#   '17.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo',
#   'Valdelacierva'],
#  ['139',
#   'France',
#   'Le',
#   '90',
#   '18.0',
#   'Languedoc-Roussillon',
#   'Coteaux du Languedoc Pic Saint Loup',
#   'Rosé',
#   'Château de Lancyre'],
#  ['141',
#   'US',
#   'Rte Blanc',
#   '90',
#   '28.0',
#   'California',
#   'Napa Valley',
#   'Sauvignon Blanc',
#   'Clif Family'],
#  ['142',
#   'US',
#   'Hook Vineyard',
#   '90',
#   '25.0',
#   'California',
#   'Santa Lucia Highlands',
#   'Grenache',
#   'Santa Cruz Mountain Vineyard'],
#  ['144',
#   'US',
#   'Jespersen Ranch',
#   '90',
#   '24.0',
#   'California',
#   'Edna Valley',
#   'Albariño',
#   'Stephen Ross'],
#  ['146',
#   'US',
#   'Estate Grown',
#   '90',
#   '36.0',
#   'California',
#   'Napa Valley',
#   'Zinfandel',
#   'Grgich Hills'],
#  ['152',
#   'Spain',
#   'Brut Reserva',
#   '89',
#   '17.0',
#   'Catalonia',
#   'Cava',
#   'Sparkling Blend',
#   'Bohigas'],
#  ['158',
#   'Spain',
#   'Viña Real Gran Reserva',
#   '89',
#   '44.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo',
#   'CVNE'],
#  ['160',
#   'US',
#   'Range 30 West',
#   '89',
#   '42.0',
#   'California',
#   'Happy Canyon of Santa Barbara',
#   'Bordeaux-style Red Blend',
#   'Foxen 7200'],
#  ['162',
#   'Spain',
#   'Gaudium',
#   '89',
#   '44.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo Blend',
#   'Marqués de Cáceres'],
#  ['164',
#   'US',
#   'Mill Road Vineyard',
#   '89',
#   '23.0',
#   'California',
#   'Paso Robles',
#   'Viognier',
#   'Eberle'],
#  ['165',
#   'US',
#   'Freedom Hill Vineyard',
#   '89',
#   '36.0',
#   'Oregon',
#   'Willamette Valley',
#   'Pinot Noir',
#   'Silvan Ridge'],
#  ['166',
#   'Italy',
#   'Le Redini',
#   '89',
#   '25.0',
#   'Tuscany',
#   'Toscana',
#   'Red Blend',
#   'Tenuta degli Dei'],
#  ['167',
#   'Italy',
#   'Il Guardiano',
#   '89',
#   '22.0',
#   'Tuscany',
#   'Toscana',
#   'Red Blend',
#   'Poggio Mandorlo'],
#  ['169',
#   'US',
#   'Del Arroyo Vineyard',
#   '89',
#   '25.0',
#   'California',
#   'Livermore Valley',
#   'Chardonnay',
#   'Occasio'],
#  ['173',
#   'US',
#   'Charles Vineyard Clone O5',
#   '89',
#   '49.0',
#   'California',
#   'Anderson Valley',
#   'Pinot Noir',
#   'Foursight'],
#  ['174',
#   'France',
#   'Héritages Elevé en Foudres de Chêne',
#   '89',
#   '16.0',
#   'Rhône Valley',
#   'Côtes du Rhône',
#   'Rhône-style Red Blend',
#   'Ogier'],
#  ['175',
#   'Spain',
#   'Gran Bajoz',
#   '89',
#   '30.0',
#   'Northern Spain',
#   'Toro',
#   'Tinta de Toro',
#   'Pagos del Rey'],
#  ['176',
#   'Italy',
#   'Palazzo Altesi',
#   '89',
#   '40.0',
#   'Tuscany',
#   'Toscana',
#   'Sangiovese',
#   'Altesino'],
#  ['177',
#   'Italy',
#   'Il Borgo',
#   '89',
#   '57.0',
#   'Tuscany',
#   'Toscana',
#   'Red Blend',
#   'Cabreo'],
#  ['178',
#   'US',
#   'Lot 525',
#   '89',
#   '29.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Cameron Hughes'],
#  ['181',
#   'US',
#   'Estate Reserve',
#   '88',
#   '25.0',
#   'California',
#   'Paso Robles',
#   'Syrah',
#   'San Simeon'],
#  ['182',
#   'US',
#   'Sonatera Vineyard',
#   '88',
#   '49.0',
#   'California',
#   'Sonoma Coast',
#   'Pinot Noir',
#   'Siduri'],
#  ['183',
#   'US',
#   'Boushey Vineyard',
#   '88',
#   '20.0',
#   'Washington',
#   'Yakima Valley',
#   'Picpoul',
#   'Syncline'],
#  ['184',
#   'Argentina',
#   'Trinità Grand Reserve',
#   '88',
#   '26.0',
#   'Mendoza Province',
#   'Luján de Cuyo',
#   'Bordeaux-style Red Blend',
#   'Piattelli'],
#  ['185',
#   'US',
#   'Entwined',
#   '88',
#   '34.0',
#   'Washington',
#   'Columbia Valley (WA)',
#   'Bordeaux-style Red Blend',
#   'Pondera'],
#  ['186',
#   'US',
#   'French Camp Vineyard',
#   '88',
#   '38.0',
#   'California',
#   'Paso Robles',
#   'Zinfandel',
#   'Tobin James'],
#  ['187',
#   'US',
#   'French Camp Vineyard',
#   '88',
#   '38.0',
#   'California',
#   'Paso Robles',
#   'Zinfandel',
#   'Tobin James'],
#  ['188',
#   'Spain',
#   'Sobre Lías',
#   '88',
#   '25.0',
#   'Northern Spain',
#   'Valdeorras',
#   'Godello',
#   'Valdesil'],
#  ['189',
#   'Spain',
#   'Negre',
#   '87',
#   '22.0',
#   'Catalonia',
#   'Montsant',
#   'Red Blend',
#   'Jaspi'],
#  ['190',
#   'Argentina',
#   'Reserve',
#   '87',
#   '15.0',
#   'Mendoza Province',
#   'Tupungato',
#   'Malbec',
#   'Tupun'],
#  ['197',
#   'US',
#   'Rosé of',
#   '87',
#   '18.0',
#   'Washington',
#   'Columbia Valley (WA)',
#   'Malbec',
#   'Hamilton'],
#  ['198',
#   'US',
#   'Ingle Vineyard Unoaked',
#   '87',
#   '18.0',
#   'New York',
#   'Finger Lakes',
#   'Chardonnay',
#   'Heron Hill'],
#  ['199',
#   'US',
#   'Semi-Dry',
#   '87',
#   '14.0',
#   'New York',
#   'Finger Lakes',
#   'Riesling',
#   'Heron Hill'],
#  ['200',
#   'US',
#   'Semi-Dry',
#   '87',
#   '14.0',
#   'New York',
#   'Finger Lakes',
#   'Riesling',
#   'Fox Run'],
#  ['201',
#   'US',
#   'Ice Wine',
#   '87',
#   '40.0',
#   'New York',
#   'Finger Lakes',
#   'Cabernet Franc',
#   'Glenora'],
#  ['208',
#   'US',
#   'Weinbau',
#   '87',
#   '32.0',
#   'Washington',
#   'Wahluke Slope',
#   'Grenache',
#   'Sol Stone'],
#  ['209',
#   'Spain',
#   'Yá Cuvée 23 Brut Rosé',
#   '87',
#   '18.0',
#   'Catalonia',
#   'Cava',
#   'Sparkling Blend',
#   'Sumarroca'],
#  ['211',
#   'Italy',
#   'Nervo',
#   '93',
#   '49.0',
#   'Piedmont',
#   'Barbaresco',
#   'Nebbiolo',
#   'Rizzi'],
#  ['212',
#   'US',
#   'Rocky Ridge Vineyard',
#   '93',
#   '50.0',
#   'California',
#   'Rockpile',
#   'Zinfandel',
#   'Robert Biale'],
#  ['213',
#   'Italy',
#   'Fausoni',
#   '93',
#   '58.0',
#   'Piedmont',
#   'Barbaresco',
#   'Nebbiolo',
#   'Sottimano'],
#  ['214',
#   'France',
#   'Rosacker Grand Cru',
#   '93',
#   '39.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Domaine Jean-Luc Mader'],
#  ['215',
#   'France',
#   'Clos Häuserer Wintzenheim',
#   '93',
#   '65.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Domaine Zind-Humbrecht'],
#  ['218',
#   'France',
#   'Pfingstberg Paradis Grand Cru',
#   '93',
#   '42.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Domaine François Schmitt'],
#  ['219',
#   'France',
#   'Altenberg de Bergheim Grand Cru Vieilles Vignes',
#   '93',
#   '61.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Gustave Lorentz'],
#  ['220',
#   'US',
#   'Collaboration Series VI Ciel du Cheval Vineyard',
#   '93',
#   '58.0',
#   'Washington',
#   'Red Mountain',
#   'G-S-M',
#   'Force Majeure'],
#  ['221',
#   'US',
#   'Hastings Ranch Vineyard',
#   '93',
#   '38.0',
#   'California',
#   'Paso Robles',
#   'Mourvèdre',
#   'Anglim'],
#  ['222',
#   'France',
#   'Heissenberg',
#   '93',
#   '48.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Domaine Ostertag'],
#  ['223',
#   'US',
#   'Stagecoach Vineyards The Biale Block',
#   '93',
#   '50.0',
#   'California',
#   'Napa Valley',
#   'Zinfandel',
#   'Robert Biale'],
#  ['224',
#   'Italy',
#   'Pajorè',
#   '93',
#   '58.0',
#   'Piedmont',
#   'Barbaresco',
#   'Nebbiolo',
#   'Sottimano'],
#  ['226',
#   'US',
#   'Estate',
#   '93',
#   '50.0',
#   'California',
#   'Fort Ross-Seaview',
#   'Syrah',
#   'Red Car'],
#  ['227',
#   'US',
#   'Collaboration Series V Ciel du Cheval Vineyard',
#   '93',
#   '80.0',
#   'Washington',
#   'Red Mountain',
#   'Cabernet Sauvignon',
#   'Force Majeure'],
#  ['228',
#   'US',
#   'White Hawk Vineyard',
#   '93',
#   '40.0',
#   'California',
#   'Santa Barbara County',
#   'Syrah',
#   'Mulvane Wine Co.'],
#  ['230',
#   'US',
#   'Double Canyon Vineyard',
#   '93',
#   '48.0',
#   'Washington',
#   'Horse Heaven Hills',
#   'Cabernet Sauvignon',
#   'Double Canyon'],
#  ['231',
#   'US',
#   'Red Rock Terrace',
#   '93',
#   '200.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Diamond Creek'],
#  ['232',
#   'US',
#   'Ciel du Cheval Vineyard',
#   '93',
#   '39.0',
#   'Washington',
#   'Red Mountain',
#   'Petit Verdot',
#   'Côtes de Ciel'],
#  ['233',
#   'US',
#   'Kingpin',
#   '93',
#   '62.0',
#   'Washington',
#   'Red Mountain',
#   'Cabernet Sauvignon',
#   'Sparkman'],
#  ['235',
#   'France',
#   'Domaine Saint-Rémy Schlosberg Grand Cru',
#   '92',
#   '35.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Domaine Ehrhart'],
#  ['236',
#   'France',
#   'Pfersigberg Grand Cru',
#   '92',
#   '48.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Domaine Zinck'],
#  ['237',
#   'France',
#   'Calcaire',
#   '92',
#   '55.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Domaine Zind-Humbrecht'],
#  ['239',
#   'Italy',
#   'Coste Rubin',
#   '92',
#   '69.0',
#   'Piedmont',
#   'Barbaresco',
#   'Nebbiolo',
#   'Fontanafredda'],
#  ['246',
#   'US',
#   'Estate',
#   '88',
#   '36.0',
#   'Oregon',
#   'McMinnville',
#   'Pinot Noir',
#   'Coeur de Terre'],
#  ['248',
#   'US',
#   'Limited Selection',
#   '88',
#   '24.0',
#   'California',
#   'Central Coast',
#   'Chardonnay',
#   'Daniel Gehrs'],
#  ['249',
#   'US',
#   "Cuvée Luke Saralee's Vineyard",
#   '88',
#   '30.0',
#   'California',
#   'Russian River Valley',
#   'Rhône-style White Blend',
#   'Davis Family'],
#  ['252',
#   'US',
#   "Wits' End",
#   '88',
#   '60.0',
#   'Oregon',
#   'Chehalem Mountains',
#   'Pinot Noir',
#   'Roco'],
#  ['253',
#   'US',
#   'Toyon Farm',
#   '88',
#   '54.0',
#   'California',
#   'Carneros',
#   'Pinot Noir',
#   'Saintsbury'],
#  ['254',
#   'US',
#   'Early',
#   '88',
#   '15.0',
#   'Oregon',
#   'Willamette Valley',
#   'Muscat',
#   'Silvan Ridge'],
#  ['255',
#   'Italy',
#   'Bussia',
#   '88',
#   '56.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Silvano Bolmida'],
#  ['256',
#   'US',
#   'Estate',
#   '88',
#   '20.0',
#   'California',
#   'Napa Valley',
#   'Sauvignon Blanc',
#   'St. Supéry'],
#  ['257',
#   'US',
#   'Guidotti Vineyard',
#   '88',
#   '61.0',
#   'California',
#   'Santa Lucia Highlands',
#   'Pinot Noir',
#   'Testarossa'],
#  ['259',
#   'Spain',
#   'Prestigio',
#   '88',
#   '30.0',
#   'Northern Spain',
#   'Cigales',
#   'Tempranillo',
#   'Val de Los Frailes'],
#  ['260',
#   'Spain',
#   'Crianza',
#   '88',
#   '17.0',
#   'Central Spain',
#   'La Mancha',
#   'Tempranillo Blend',
#   'Yuntero'],
#  ['262',
#   'US',
#   'Querida',
#   '88',
#   '40.0',
#   'California',
#   'Paso Robles',
#   'Cabernet Sauvignon-Merlot',
#   'Oso Libre'],
#  ['263',
#   'US',
#   'Primoroso',
#   '88',
#   '39.0',
#   'California',
#   'Paso Robles',
#   'Red Blend',
#   'Oso Libre'],
#  ['264',
#   'Italy',
#   "del Comune di Serralunga d'Alba",
#   '88',
#   '49.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Palladino'],
#  ['265',
#   'France',
#   'Domaine de Saint-Pierre',
#   '88',
#   '23.0',
#   'Loire Valley',
#   'Sancerre',
#   'Sauvignon Blanc',
#   'Pierre Prieur et Fils'],
#  ['267',
#   'US',
#   "Anna's Estate Vineyard",
#   '88',
#   '32.0',
#   'California',
#   'Paso Robles',
#   'Mourvèdre',
#   'Adelaida'],
#  ['269',
#   'Argentina',
#   'Single Vineyard Reserva',
#   '88',
#   '15.0',
#   'Mendoza Province',
#   'Agrelo',
#   'Cabernet Sauvignon',
#   'Lamadrid'],
#  ['270',
#   'France',
#   'Pertuisots Premier Cru',
#   '92',
#   '92.0',
#   'Burgundy',
#   'Beaune',
#   'Pinot Noir',
#   'Domaine de Bellene'],
#  ['271',
#   'France',
#   'Clos du Cailleret Premier Cru',
#   '92',
#   '94.0',
#   'Burgundy',
#   'Chassagne-Montrachet',
#   'Chardonnay',
#   'Domaine Vincent Girardin'],
#  ['272',
#   'US',
#   'Haynes Vineyard',
#   '92',
#   '58.0',
#   'California',
#   'Coombsville',
#   'Chardonnay',
#   'Failla'],
#  ['273',
#   'US',
#   'Suzuri Series Shake Ridge Ranch',
#   '92',
#   '50.0',
#   'California',
#   'Amador County',
#   'Rhône-style Red Blend',
#   'Gallica'],
#  ['274',
#   'US',
#   'Vintage Brut',
#   '92',
#   '48.0',
#   'California',
#   'Russian River Valley',
#   'Sparkling Blend',
#   'J Vineyards & Winery'],
#  ['276',
#   'Italy',
#   'Sirmian',
#   '92',
#   '27.0',
#   'Northeastern Italy',
#   'Alto Adige',
#   'Pinot Bianco',
#   'Nals Margreid'],
#  ['279',
#   'US',
#   'Solomon Hills Vineyard',
#   '92',
#   '43.0',
#   'California',
#   'Santa Maria Valley',
#   'Pinot Noir',
#   'Ryan Cochrane'],
#  ['280',
#   'Italy',
#   'Monte Carbonare',
#   '92',
#   '33.0',
#   'Veneto',
#   'Soave Classico',
#   'Garganega',
#   'Suavia'],
#  ['281',
#   'Italy',
#   'Quarz',
#   '92',
#   '60.0',
#   'Northeastern Italy',
#   'Alto Adige',
#   'Sauvignon',
#   'Cantina Terlano'],
#  ['283',
#   'France',
#   'Réserve',
#   '92',
#   '30.0',
#   'Bordeaux',
#   'Graves',
#   'Bordeaux-style Red Blend',
#   'Château Haut Selve'],
#  ['284',
#   'US',
#   'Lampyridae Vineyards',
#   '92',
#   '100.0',
#   'California',
#   'Mount Veeder',
#   'Cabernet Sauvignon',
#   'Communication Block'],
#  ['285',
#   'US',
#   'Le Mistral Vineyard',
#   '92',
#   '35.0',
#   'California',
#   'Monterey County',
#   'Syrah',
#   'Baker & Brain'],
#  ['286',
#   'France',
#   'Les Charmes Dessus',
#   '91',
#   '60.0',
#   'Burgundy',
#   'Santenay',
#   'Chardonnay',
#   'Domaine de Bellene'],
#  ['287',
#   'France',
#   'Cuvée Germain',
#   '91',
#   '16.0',
#   'Southwest France',
#   'Côtes du Tarn',
#   'Bordeaux-style Red Blend',
#   "Domaine D'en Ségur"],
#  ['288',
#   'France',
#   'Quintessence',
#   '91',
#   '40.0',
#   'Burgundy',
#   'Pouilly-Fuissé',
#   'Chardonnay',
#   'Domaine Sangouard-Guyot'],
#  ['289',
#   'US',
#   'Clay Court',
#   '91',
#   '60.0',
#   'Oregon',
#   'Willamette Valley',
#   'Pinot Noir',
#   'Elk Cove'],
#  ['293',
#   'US',
#   'Kruse Vineyards',
#   '91',
#   '42.0',
#   'California',
#   'Paso Robles',
#   'Syrah',
#   'Jack Creek'],
#  ['295',
#   'US',
#   'Rosé of',
#   '91',
#   '20.0',
#   'California',
#   'Napa Valley',
#   'Pinot Noir',
#   'Brick & Mortar'],
#  ['296',
#   'Italy',
#   'Prail',
#   '91',
#   '25.0',
#   'Northeastern Italy',
#   'Alto Adige',
#   'Sauvignon',
#   'Colterenzio'],
#  ['297',
#   'Italy',
#   'Puiten',
#   '91',
#   '23.0',
#   'Northeastern Italy',
#   'Alto Adige',
#   'Pinot Grigio',
#   'Colterenzio'],
#  ['298',
#   'US',
#   'Estate Grown',
#   '91',
#   '38.0',
#   'California',
#   'Carneros',
#   'Pinot Noir',
#   'Cuvaison'],
#  ['299',
#   'US',
#   'Nova Vineyard',
#   '91',
#   '32.0',
#   'California',
#   'Clear Lake',
#   'Zinfandel',
#   'De Loach'],
#  ['300',
#   'US',
#   'The Funk Estate',
#   '94',
#   '60.0',
#   'Washington',
#   'Walla Walla Valley (WA)',
#   'Syrah',
#   'Saviah'],
#  ['301',
#   'US',
#   'Estate Bottled',
#   '94',
#   '30.0',
#   'California',
#   'Napa Valley',
#   'Riesling',
#   'Smith-Madrone'],
#  ['302',
#   'Italy',
#   "Vigneto Monte Sant'Urbano",
#   '94',
#   '85.0',
#   'Veneto',
#   'Amarone della Valpolicella Classico',
#   'Red Blend',
#   'Speri'],
#  ['303',
#   'US',
#   'White',
#   '94',
#   '30.0',
#   'California',
#   'Napa Valley',
#   'Riesling',
#   'Stony Hill'],
#  ['304',
#   'US',
#   'Sierra Madre Vineyard',
#   '94',
#   '65.0',
#   'California',
#   'Santa Maria Valley',
#   'Pinot Noir',
#   'Testarossa'],
#  ['306',
#   'US',
#   'Bergström Vineyard',
#   '94',
#   '90.0',
#   'Oregon',
#   'Dundee Hills',
#   'Pinot Noir',
#   'Bergström'],
#  ['307',
#   'US',
#   'Angel Hawk',
#   '94',
#   '85.0',
#   'California',
#   'Anderson Valley',
#   'Pinot Noir',
#   'Black Kite'],
#  ['308',
#   'US',
#   'King Ridge Vineyard Hirsch Selection',
#   '94',
#   '70.0',
#   'California',
#   'Fort Ross-Seaview',
#   'Pinot Noir',
#   'Blue Farm'],
#  ['309',
#   'US',
#   'Evenstad Reserve',
#   '94',
#   '70.0',
#   'Oregon',
#   'Willamette Valley',
#   'Pinot Noir',
#   'Domaine Serene'],
#  ['310',
#   'US',
#   'Bacigalupi Vineyard',
#   '94',
#   '60.0',
#   'California',
#   'Russian River Valley',
#   'Pinot Noir',
#   'Gary Farrell'],
#  ['311',
#   'Italy',
#   'Contrada Salvarenza Vecchie Vigne',
#   '94',
#   '38.0',
#   'Veneto',
#   'Soave Classico',
#   'Garganega',
#   'Gini'],
#  ['312',
#   'Italy',
#   'La Froscà',
#   '94',
#   '29.0',
#   'Veneto',
#   'Soave Classico',
#   'Garganega',
#   'Gini'],
#  ['313',
#   'US',
#   'Outer Limits',
#   '94',
#   '155.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Parallel'],
#  ['314',
#   'US',
#   'Durant Vineyard Bishop Block',
#   '94',
#   '48.0',
#   'Oregon',
#   'Dundee Hills',
#   'Pinot Noir',
#   'Patricia Green Cellars'],
#  ['315',
#   'US',
#   'Godspeed',
#   '94',
#   '95.0',
#   'California',
#   'Mount Veeder',
#   'Cabernet Sauvignon',
#   'Sbragia'],
#  ['316',
#   'US',
#   'Tognetti Vineyard Brut',
#   '94',
#   '80.0',
#   'California',
#   'Carneros',
#   'Sparkling Blend',
#   'Schramsberg'],
#  ['317',
#   'US',
#   'Ribbon Ridge Estate',
#   '94',
#   '49.0',
#   'Oregon',
#   'Ribbon Ridge',
#   'Pinot Noir',
#   'Trisaetum'],
#  ['318',
#   'France',
#   'Château Montus',
#   '94',
#   '35.0',
#   'Southwest France',
#   'Madiran',
#   'Tannat-Cabernet',
#   'Vignobles Brumont'],
#  ['319',
#   'US',
#   'Old Stones',
#   '94',
#   '50.0',
#   'Washington',
#   'Walla Walla Valley (WA)',
#   'Syrah',
#   'Waters'],
#  ['320',
#   'France',
#   'La Bégude',
#   '94',
#   '44.0',
#   'Provence',
#   'Bandol',
#   'Provence red blend',
#   'Domaine de la Bégude'],
#  ['321',
#   'Spain',
#   'QP',
#   '94',
#   '68.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo Blend',
#   'Bodega Classica'],
#  ['324',
#   'US',
#   'Pellet Vineyard',
#   '94',
#   '95.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Pellet Estate'],
#  ['325',
#   'France',
#   'La Bégude',
#   '94',
#   '44.0',
#   'Provence',
#   'Bandol',
#   'Provence red blend',
#   'Domaine de la Bégude'],
#  ['326',
#   'Argentina',
#   'Alta Barrancas Vineyards',
#   '94',
#   '50.0',
#   'Mendoza Province',
#   'Mendoza',
#   'Cabernet Sauvignon',
#   'Pascual Toso'],
#  ['327',
#   'France',
#   'Garrus',
#   '94',
#   '100.0',
#   'Provence',
#   'Côtes de Provence',
#   'Rosé',
#   "Château d'Esclans"],
#  ['328',
#   'France',
#   'Cuvée Marguerite Massaut',
#   '94',
#   '70.0',
#   'Southwest France',
#   'Cahors',
#   'Malbec',
#   'Château Lagrézette'],
#  ['329',
#   'US',
#   'Aurora Vineyard',
#   '94',
#   '63.0',
#   'Oregon',
#   'Willamette Valley',
#   'Chardonnay',
#   'Ponzi'],
#  ['330',
#   'Italy',
#   'Monvigliero',
#   '91',
#   '75.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Fratelli Alessandria'],
#  ['332',
#   'US',
#   'Latro',
#   '91',
#   '50.0',
#   'California',
#   'Knights Valley',
#   'Cabernet Sauvignon',
#   'Galerie'],
#  ['333',
#   'Spain',
#   'Etiqueta Ambar',
#   '91',
#   '22.0',
#   'Galicia',
#   'Rías Baixas',
#   'Albariño',
#   'Granbazán'],
#  ['334',
#   'US',
#   'Grieve Family Vineyard',
#   '91',
#   '45.0',
#   'California',
#   'Napa Valley',
#   'Sauvignon Blanc',
#   'Grieve'],
#  ['336',
#   'US',
#   'XCV',
#   '91',
#   '38.0',
#   'California',
#   'Paso Robles Willow Creek District',
#   'Rhône-style White Blend',
#   'Jada Vineyard & Winery'],
#  ['338',
#   'US',
#   'Rosé of',
#   '91',
#   '22.0',
#   'California',
#   'Knights Valley',
#   'Syrah',
#   'Lawer'],
#  ['340',
#   'Italy',
#   'Coste di Rose',
#   '91',
#   '90.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Marchesi di Barolo'],
#  ['341',
#   'US',
#   'Emblem Oso Vineyard',
#   '91',
#   '60.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Michael Mondavi Family Estate'],
#  ['342',
#   'Italy',
#   'Brunate',
#   '91',
#   '115.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Oddero'],
#  ['343',
#   'US',
#   'Estate Cuvée',
#   '91',
#   '55.0',
#   'California',
#   'Russian River Valley',
#   'Pinot Noir',
#   'Small Vines'],
#  ['346',
#   'US',
#   'Lone Oak Vineyard',
#   '91',
#   '48.0',
#   'California',
#   'Santa Lucia Highlands',
#   'Chardonnay',
#   'Testarossa'],
#  ['347',
#   'US',
#   'Starr Ridge Vineyard Estate',
#   '91',
#   '40.0',
#   'California',
#   'Russian River Valley',
#   'Chardonnay',
#   'Thomas George'],
#  ['349',
#   'Italy',
#   'Paesi Tuoi',
#   '91',
#   '60.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Vite Colte'],
#  ['350',
#   'US',
#   'Sierra Madre Vineyard',
#   '91',
#   '50.0',
#   'California',
#   'Santa Maria Valley',
#   'Chardonnay',
#   'Wedell Cellars'],
#  ['351',
#   'US',
#   'Juliard Vineyard',
#   '91',
#   '48.0',
#   'Oregon',
#   'Dundee Hills',
#   'Pinot Noir',
#   'Winderlea'],
#  ['352',
#   'France',
#   'Grand Cru Blanc de Blancs Chouilly Brut',
#   '91',
#   '54.0',
#   'Champagne',
#   'Champagne',
#   'Chardonnay',
#   'A.R. Lenoble\xa0'],
#  ['354',
#   'US',
#   'Brut Rosé',
#   '91',
#   '50.0',
#   'Oregon',
#   'Willamette Valley',
#   'Sparkling Blend',
#   'Argyle'],
#  ['356',
#   'US',
#   "Rosella's Vineyard",
#   '91',
#   '40.0',
#   'California',
#   'Santa Lucia Highlands',
#   'Chardonnay',
#   'Bernardus'],
#  ['358',
#   'Italy',
#   'Parej',
#   '91',
#   '85.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Icardi'],
#  ['359',
#   'Spain',
#   'Crianza',
#   '91',
#   '32.0',
#   'Northern Spain',
#   'Ribera del Duero',
#   'Tempranillo',
#   'Matarromera'],
#  ['360',
#   'US',
#   'Cuore della Vigne',
#   '90',
#   '41.0',
#   'California',
#   'Paso Robles',
#   'Red Blend',
#   'Le Vigne'],
#  ['361',
#   'US',
#   'Kiler Grove Vineyard',
#   '90',
#   '27.0',
#   'California',
#   'Paso Robles Willow Creek District',
#   'Ugni Blanc',
#   'Paix Sur Terre'],
#  ['362',
#   'US',
#   "Winemaker's Reserve",
#   '90',
#   '29.0',
#   'Oregon',
#   'Umpqua Valley',
#   'Grüner Veltliner',
#   'Reustle'],
#  ['363',
#   'France',
#   'Galets Oligocène',
#   '90',
#   '33.0',
#   'Alsace',
#   'Alsace',
#   'Pinot Noir',
#   'Domaine Bott-Geyl'],
#  ['368',
#   'France',
#   'Vieilles Vignes',
#   '90',
#   '27.0',
#   'Alsace',
#   'Alsace',
#   'Sylvaner',
#   'Domaine Ostertag'],
#  ['369',
#   'France',
#   'Vieilles Vignes',
#   '90',
#   '22.0',
#   'Alsace',
#   'Alsace',
#   'Chasselas',
#   'Domaine Schoffit'],
#  ['370',
#   'France',
#   'Zind',
#   '90',
#   '30.0',
#   'Alsace',
#   'Alsace',
#   'Alsace white blend',
#   'Domaine Zind-Humbrecht'],
#  ['372',
#   'US',
#   'Sisters Estate',
#   '90',
#   '45.0',
#   'Oregon',
#   'Dundee Hills',
#   'Pinot Noir',
#   'The Eyrie Vineyards'],
#  ['373',
#   'France',
#   'Domaine du Pavillon Clos des Ursulines',
#   '90',
#   '80.0',
#   'Burgundy',
#   'Pommard',
#   'Pinot Noir',
#   'Albert Bichot'],
#  ['381',
#   'US',
#   'Classic Collection',
#   '90',
#   '24.0',
#   'California',
#   'Napa Valley',
#   'Merlot',
#   'Napa Cellars'],
#  ['382',
#   'US',
#   'Rector Creek Vineyard',
#   '90',
#   '80.0',
#   'California',
#   'Napa Valley',
#   'Red Blend',
#   'Paraduxx'],
#  ['383',
#   'Spain',
#   'Reserva',
#   '90',
#   '35.0',
#   'Northern Spain',
#   'Ribera del Duero',
#   'Tempranillo',
#   'Quintana de Cue'],
#  ['385',
#   'Spain',
#   'Orquestal',
#   '90',
#   '28.0',
#   'Central Spain',
#   'La Mancha',
#   'Tempranillo',
#   'Casa del Valle'],
#  ['387',
#   'US',
#   'Olson Vineyard',
#   '90',
#   '28.0',
#   'California',
#   'Dry Creek Valley',
#   'Cabernet Sauvignon',
#   'Joleté'],
#  ['388',
#   'US',
#   'The Truant',
#   '90',
#   '36.0',
#   'California',
#   'California',
#   'Rhône-style Red Blend',
#   'Prospect 772'],
#  ['390',
#   'US',
#   "Proprietor's Reserve",
#   '90',
#   '50.0',
#   'California',
#   'Central Coast',
#   'Chardonnay',
#   'Hearst Ranch'],
#  ['391',
#   'US',
#   'Cabovation Destiny Vineyards Mt. Christo Block Reserve',
#   '90',
#   '75.0',
#   'California',
#   'Paso Robles',
#   'Cabernet Sauvignon',
#   'Hunt Cellars'],
#  ['393',
#   'US',
#   'Seven Hills Vineyard',
#   '90',
#   '46.0',
#   'Washington',
#   'Walla Walla Valley (WA)',
#   'Malbec',
#   'Merry Cellars'],
#  ['394',
#   'Canada',
#   'Compendium',
#   '90',
#   '70.0',
#   'British Columbia',
#   'Okanagan Valley',
#   'Bordeaux-style Red Blend',
#   'Mission Hill'],
#  ['395',
#   'Spain',
#   'Albariño de Fefiñanes',
#   '90',
#   '26.0',
#   'Galicia',
#   'Rías Baixas',
#   'Albariño',
#   'Palacio de Fefiñanes'],
#  ['397',
#   'Italy',
#   'Villa al Cortile Riserva',
#   '90',
#   '60.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Piccini'],
#  ['398',
#   'Italy',
#   'Riserva',
#   '90',
#   '75.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Pietranera'],
#  ['400',
#   'Italy',
#   'Riserva',
#   '90',
#   '95.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Renieri'],
#  ['403',
#   'US',
#   'Trois Fleurs',
#   '90',
#   '20.0',
#   'California',
#   'Santa Ynez Valley',
#   'White Blend',
#   'Carlson'],
#  ['404',
#   'France',
#   'Cuvée Setier',
#   '90',
#   '27.0',
#   'Rhône Valley',
#   'Côtes du Rhône Villages',
#   'Rhône-style Red Blend',
#   'Château Pégau'],
#  ['405',
#   'France',
#   'Cuvée de Nalys',
#   '90',
#   '20.0',
#   'Rhône Valley',
#   'Châteauneuf-du-Pape',
#   'Rhône-style Red Blend',
#   'Kirkland Signature'],
#  ['406',
#   'US',
#   "Kate's + B's",
#   '90',
#   '75.0',
#   'California',
#   'Alexander Valley',
#   'Cabernet Sauvignon',
#   'Medlock Ames'],
#  ['407',
#   'US',
#   'New Generation',
#   '90',
#   '28.0',
#   'California',
#   'Russian River Valley',
#   'Sauvignon Blanc',
#   'Passaggio'],
#  ['409',
#   'US',
#   'Signpost',
#   '90',
#   '22.0',
#   'California',
#   'Sonoma Coast',
#   'Chardonnay',
#   'Trig Point'],
#  ['410',
#   'Spain',
#   'Mirlo Blanco',
#   '90',
#   '49.0',
#   'Spain Other',
#   'Spain',
#   'White Blend',
#   'Valquejigoso'],
#  ['415',
#   'US',
#   'Elevation Annadel Gap Vineyard Estate',
#   '90',
#   '38.0',
#   'California',
#   'Sonoma Valley',
#   'Rhône-style Red Blend',
#   'Westwood'],
#  ['417',
#   'Italy',
#   'Berardo Riserva',
#   '90',
#   '30.0',
#   'Tuscany',
#   'Chianti Classico',
#   'Sangiovese',
#   'Castello di Bossi'],
#  ['419',
#   'Italy',
#   'Riserva',
#   '90',
#   '35.0',
#   'Tuscany',
#   'Chianti Classico',
#   'Sangiovese',
#   'Cafaggio'],
#  ['421',
#   'US',
#   'Rapscallion',
#   '87',
#   '30.0',
#   'California',
#   'Paso Robles',
#   'Zinfandel',
#   'League of Rogues'],
#  ['423',
#   'US',
#   'Weinbau',
#   '87',
#   '32.0',
#   'Washington',
#   'Wahluke Slope',
#   'Grenache',
#   'Sol Stone'],
#  ['424',
#   'Spain',
#   'Yá Cuvée 23 Brut Rosé',
#   '87',
#   '18.0',
#   'Catalonia',
#   'Cava',
#   'Sparkling Blend',
#   'Sumarroca'],
#  ['425',
#   'Spain',
#   'Crianza',
#   '87',
#   '27.0',
#   'Northern Spain',
#   'Ribera del Duero',
#   'Tempranillo',
#   'Trus'],
#  ['428',
#   'US',
#   'Chandler Vineyard',
#   '87',
#   '30.0',
#   'California',
#   'Livermore Valley',
#   'Chardonnay',
#   'McGrail'],
#  ['429',
#   'US',
#   'Freakshow',
#   '87',
#   '20.0',
#   'California',
#   'Lodi',
#   'Cabernet Sauvignon',
#   'Michael David'],
#  ['431',
#   'US',
#   'Southern',
#   '87',
#   '22.0',
#   'Washington',
#   'Yakima Valley',
#   'Rhône-style White Blend',
#   'Cairdeas'],
#  ['432',
#   'Italy',
#   'Vigna Poggio Ronconi',
#   '87',
#   '75.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Citille di Sopra'],
#  ['433',
#   'Italy',
#   'Filo di Seta',
#   '87',
#   '98.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Castello Romitorio'],
#  ['438',
#   'Italy',
#   'Pagliatura',
#   '87',
#   '28.0',
#   'Tuscany',
#   'Maremma Toscana',
#   'Vermentino',
#   'Fattoria di Magliano'],
#  ['439',
#   'Spain',
#   'Buleria Fino',
#   '87',
#   '25.0',
#   'Andalucia',
#   'Jerez',
#   'Sherry',
#   'Bodegas Dios Baco S.L.'],
#  ['440',
#   'Italy',
#   'Scirè',
#   '87',
#   '17.0',
#   'Tuscany',
#   'Bolgheri',
#   'Red Blend',
#   'Ceralti'],
#  ['442',
#   'Spain',
#   'Crianza',
#   '87',
#   '15.0',
#   'Northern Spain',
#   'Ribera del Duero',
#   'Tempranillo',
#   'Condado de Oriza'],
#  ['443',
#   'Spain',
#   'Premium',
#   '87',
#   '16.0',
#   'Andalucia',
#   'Manzanilla-Sanlúcar de Barrameda',
#   'Sherry',
#   'Delgado Zuleta'],
#  ['444',
#   'Spain',
#   'Roble 4 Meses en Barrica',
#   '87',
#   '15.0',
#   'Northern Spain',
#   'Ribera del Duero',
#   'Tempranillo Blend',
#   'Señorío de Sotillo'],
#  ['446',
#   'Spain',
#   'Brunus',
#   '87',
#   '28.0',
#   'Catalonia',
#   'Montsant',
#   'Red Blend',
#   'Portal del Montsant'],
#  ['447',
#   'Italy',
#   'Riserva',
#   '87',
#   '52.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'La Collina dei Lecci'],
#  ['448',
#   'Italy',
#   'Vigna Manapetra Riserva',
#   '87',
#   '58.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Fattoria La Lecciaia'],
#  ['451',
#   'Italy',
#   'Senza Solfiti Aggiunti',
#   '86',
#   '15.0',
#   'Veneto',
#   'Soave',
#   'White Blend',
#   'Latium di Morini'],
#  ['452',
#   'US',
#   'Cannon Block',
#   '86',
#   '26.0',
#   'California',
#   'Knights Valley',
#   'Chardonnay',
#   'Lawer'],
#  ['455',
#   'Argentina',
#   'Alma Mora',
#   '86',
#   '10.0',
#   'Other',
#   'San Juan',
#   'Sauvignon Blanc',
#   'Finca Las Moras'],
#  ['458',
#   'US',
#   'Estate Grown Cabernet',
#   '86',
#   '35.0',
#   'Washington',
#   'Red Mountain',
#   'Rosé',
#   'Obelisco Estate'],
#  ['462',
#   'US',
#   'Porter and Plot',
#   '86',
#   '31.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Winc'],
#  ['465',
#   'US',
#   'Reserve',
#   '86',
#   '18.0',
#   'California',
#   'Mendocino County',
#   'Pinot Noir',
#   'Angeline'],
#  ['468',
#   'US',
#   'Estate Vineyard',
#   '86',
#   '24.0',
#   'California',
#   'Paso Robles',
#   'Chardonnay',
#   'Eberle'],
#  ['472',
#   'US',
#   'Osborn Ranch',
#   '86',
#   '38.0',
#   'California',
#   'Alexander Valley',
#   'Primitivo',
#   'DeLorimier'],
#  ['475',
#   'US',
#   'The Deep Six',
#   '86',
#   '32.0',
#   'California',
#   'South Coast',
#   'Red Blend',
#   'Hawk Watch Winery'],
#  ['480',
#   'US',
#   'Charles Vineyard Clone O5',
#   '89',
#   '49.0',
#   'California',
#   'Anderson Valley',
#   'Pinot Noir',
#   'Foursight'],
#  ['482',
#   'France',
#   'Bastide de Beauvert',
#   '89',
#   '11.0',
#   'Rhône Valley',
#   'Côtes du Rhône',
#   'Grenache-Syrah',
#   'Les Vignobles Foncalieu'],
#  ['483',
#   'Italy',
#   'Montesodi',
#   '89',
#   '43.0',
#   'Tuscany',
#   'Toscana',
#   'Sangiovese',
#   "Marchesi de' Frescobaldi"],
#  ['484',
#   'France',
#   'Les Gravels',
#   '89',
#   '19.0',
#   'Southwest France',
#   'Gaillac',
#   'Red Blend',
#   'Domaine Rotier'],
#  ['485',
#   'France',
#   'Les Gravels',
#   '89',
#   '28.0',
#   'Southwest France',
#   'Gaillac',
#   'White Blend',
#   'Domaine Rotier'],
#  ['489',
#   'US',
#   'Cheval Rouge Reserve',
#   '89',
#   '30.0',
#   'California',
#   'Carmel Valley',
#   'Bordeaux-style Red Blend',
#   'Boëté'],
#  ['490',
#   'Italy',
#   'Coniale',
#   '89',
#   '55.0',
#   'Tuscany',
#   'Toscana',
#   'Cabernet Sauvignon',
#   'Castellare di Castellina'],
#  ['492',
#   'US',
#   'Nicholas Estate Reserve',
#   '89',
#   '46.0',
#   'Oregon',
#   'Chehalem Mountains',
#   'Pinot Noir',
#   'Anam Cara'],
#  ['494',
#   'US',
#   'Fourplay',
#   '89',
#   '43.0',
#   'California',
#   'Santa Ynez Valley',
#   'Red Blend',
#   'Carhartt Vineyard'],
#  ['496',
#   'US',
#   'Thompson Vineyard',
#   '89',
#   '39.0',
#   'California',
#   'Santa Barbara County',
#   'Syrah',
#   'Rideau'],
#  ['497',
#   'Italy',
#   'Daniello',
#   '89',
#   '30.0',
#   'Tuscany',
#   'Toscana',
#   'Red Blend',
#   'Tenuta di Trecciano'],
#  ['498',
#   'Italy',
#   'Il Tarabuso',
#   '89',
#   '45.0',
#   'Tuscany',
#   'Toscana',
#   'Cabernet Sauvignon',
#   'Terre del Marchesato'],
#  ['500',
#   'France',
#   'Belleruche',
#   '89',
#   '15.0',
#   'Rhône Valley',
#   'Côtes du Rhône',
#   'Grenache-Syrah',
#   'M. Chapoutier'],
#  ['501',
#   'US',
#   'Paderewski Vineyard',
#   '89',
#   '65.0',
#   'California',
#   'Paso Robles',
#   'Zinfandel',
#   'Epoch Estate Wines'],
#  ['504',
#   'US',
#   'Martinelli',
#   '89',
#   '60.0',
#   'California',
#   'Paso Robles',
#   'Zinfandel',
#   'Lone Madrone'],
#  ['505',
#   'US',
#   'Momtazi Vineyard',
#   '89',
#   '44.0',
#   'Oregon',
#   'McMinnville',
#   'Pinot Noir',
#   'Kelley Fox'],
#  ['506',
#   'Spain',
#   'Val do Salnés',
#   '89',
#   '25.0',
#   'Galicia',
#   'Rías Baixas',
#   'Albariño',
#   'Mar de Frades'],
#  ['507',
#   'Italy',
#   'Carmione',
#   '89',
#   '30.0',
#   'Tuscany',
#   'Toscana',
#   'Red Blend',
#   'Pratesi'],
#  ['509',
#   'Spain',
#   'Brut',
#   '89',
#   '18.0',
#   'Catalonia',
#   'Cava',
#   'Sparkling Blend',
#   'Castellroig'],
#  ['510',
#   'US',
#   'Dutton Ranch Mill Station Vineyard',
#   '92',
#   '30.0',
#   'California',
#   'Green Valley',
#   'Chardonnay',
#   'Martin Ray'],
#  ['513',
#   'US',
#   'Black Chicken',
#   '92',
#   '45.0',
#   'California',
#   'Napa Valley',
#   'Zinfandel',
#   'Robert Biale'],
#  ['514',
#   'US',
#   'Cambium',
#   '92',
#   '125.0',
#   'California',
#   'Napa Valley',
#   'Bordeaux-style Red Blend',
#   'Sequoia Grove'],
#  ['516',
#   'US',
#   'Fergalicious',
#   '92',
#   '40.0',
#   'California',
#   'Santa Ynez Valley',
#   'Red Blend',
#   'Ferguson Crest'],
#  ['517',
#   'Canada',
#   'Cave Spring Vineyard Estate Bottled VQA',
#   '92',
#   '17.0',
#   'Ontario',
#   'Beamsville Bench',
#   'Riesling',
#   'Cave Spring'],
#  ['518',
#   'US',
#   'Loner W11-B',
#   '92',
#   '60.0',
#   'California',
#   'Santa Maria Valley',
#   'Chardonnay',
#   'Sanguis'],
#  ['520',
#   'US',
#   'Hyde Vineyard',
#   '92',
#   '68.0',
#   'California',
#   'Carneros',
#   'Chardonnay',
#   "Ram's Gate"],
#  ['522',
#   'US',
#   'Conner Lee',
#   '92',
#   '32.0',
#   'Washington',
#   'Columbia Valley (WA)',
#   'Chardonnay',
#   'Array'],
#  ['523',
#   'US',
#   'White Hawk Vineyard',
#   '92',
#   '45.0',
#   'California',
#   'Santa Barbara County',
#   'Syrah',
#   'Vie Winery'],
#  ['524',
#   'US',
#   'Celilo Vineyard',
#   '92',
#   '66.0',
#   'Washington',
#   'Columbia Gorge (WA)',
#   'Chardonnay',
#   'Woodward Canyon'],
#  ['525',
#   'France',
#   'Bruderbach Clos des Frères',
#   '92',
#   '29.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Domaine Loew'],
#  ['526',
#   'France',
#   'Jubiléé',
#   '92',
#   '63.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Hugel'],
#  ['527',
#   'US',
#   'Melville Vineyard',
#   '92',
#   '32.0',
#   'California',
#   'Sta. Rita Hills',
#   'Chardonnay',
#   'Lafond'],
#  ['528',
#   'US',
#   'Quail Hill Vineyard',
#   '92',
#   '55.0',
#   'California',
#   'Russian River Valley',
#   'Chardonnay',
#   'Lynmar'],
#  ['530',
#   'Italy',
#   'Canova',
#   '92',
#   '45.0',
#   'Piedmont',
#   'Barbaresco',
#   'Nebbiolo',
#   'Ressia'],
#  ['531',
#   'US',
#   "Kristen's Cuvee",
#   '92',
#   '20.0',
#   'California',
#   'California',
#   'Viognier',
#   'Rock Wall'],
#  ['532',
#   'Italy',
#   'Sottocastello di Novello Riserva',
#   '92',
#   '50.0',
#   'Piedmont',
#   'Barolo',
#   'Nebbiolo',
#   'Piazzo Armando'],
#  ['536',
#   'US',
#   'Nielson Vineyard',
#   '92',
#   '32.0',
#   'California',
#   'Santa Maria Valley',
#   'Chardonnay',
#   'Byron'],
#  ['538',
#   'US',
#   'Collaboration Series',
#   '92',
#   '35.0',
#   'Washington',
#   'Red Mountain',
#   'Viognier',
#   'Force Majeure'],
#  ['539',
#   'US',
#   'Fort Ross Vineyard',
#   '92',
#   '44.0',
#   'California',
#   'Fort Ross-Seaview',
#   'Chardonnay',
#   'Fort Ross'],
#  ['540',
#   'US',
#   'Monarch Mine Vineyards',
#   '90',
#   '24.0',
#   'California',
#   'Sierra Foothills',
#   'Cabernet Franc',
#   'Easton'],
#  ['543',
#   'France',
#   'Les Marconnets Premier Cru',
#   '90',
#   '50.0',
#   'Burgundy',
#   'Beaune',
#   'Pinot Noir',
#   'Labouré-Roi'],
#  ['545',
#   'US',
#   'Estate Vineyards',
#   '90',
#   '23.0',
#   'California',
#   'Central Coast',
#   'Pinot Noir',
#   'MacMurray Ranch'],
#  ['546',
#   'US',
#   'Sundawg Ridge Vineyard',
#   '90',
#   '49.0',
#   'California',
#   'Green Valley',
#   'Pinot Noir',
#   'MacPhail'],
#  ['550',
#   'France',
#   'Bastion Premier Cru',
#   '90',
#   '59.0',
#   'Burgundy',
#   'Beaune',
#   'Chardonnay',
#   'Chanson Père et Fils'],
#  ['551',
#   'France',
#   'Rosenberg',
#   '90',
#   '24.0',
#   'Alsace',
#   'Alsace',
#   'Sylvaner',
#   'Domaine Barmès-Buecher'],
#  ['553',
#   'France',
#   "L'Aplomb",
#   '90',
#   '20.0',
#   'Alsace',
#   'Alsace',
#   'White Blend',
#   'Domaine Rieflé-Landmann'],
#  ['554',
#   'France',
#   'Réserve',
#   '90',
#   '20.0',
#   'Alsace',
#   'Alsace',
#   'Pinot Blanc',
#   'Domaine Weinbach'],
#  ['557',
#   'US',
#   'Montecillo Vineyard',
#   '90',
#   '42.0',
#   'California',
#   'Sonoma Valley',
#   'Zinfandel',
#   'Ordaz Family Wines'],
#  ['558',
#   'Italy',
#   'Bianco Dry',
#   '90',
#   '22.0',
#   'Sicily & Sardinia',
#   'Noto',
#   'Moscato',
#   'Planeta'],
#  ['560',
#   'US',
#   'Guadalupe Vineyard',
#   '90',
#   '48.0',
#   'Oregon',
#   'Dundee Hills',
#   'Pinot Noir',
#   'Soléna'],
#  ['564',
#   'Spain',
#   'Fincas de la Villa Reserva',
#   '90',
#   '20.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo',
#   'Bodegas Muriel'],
#  ['565',
#   'Spain',
#   'Crianza',
#   '90',
#   '17.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo Blend',
#   'Burgo Viejo'],
#  ['566',
#   'US',
#   'Made with Organically Grown Grapes',
#   '90',
#   '22.0',
#   'California',
#   'Sierra Foothills',
#   'Merlot',
#   'Chacewater'],
#  ['570',
#   'US',
#   'Sunny View',
#   '94',
#   '62.0',
#   'California',
#   'Russian River Valley',
#   'Pinot Noir',
#   'The Calling'],
#  ['571',
#   'US',
#   'Wichmann Dundee Estate',
#   '94',
#   '49.0',
#   'Oregon',
#   'Dundee Hills',
#   'Pinot Noir',
#   'Trisaetum'],
#  ['572',
#   'France',
#   'Château Bouscassé',
#   '94',
#   '25.0',
#   'Southwest France',
#   'Madiran',
#   'Red Blend',
#   'Vignobles Brumont'],
#  ['573',
#   'US',
#   'Reserve',
#   '94',
#   '95.0',
#   'California',
#   'Rutherford',
#   'Cabernet Sauvignon',
#   'Frank Family'],
#  ['574',
#   'US',
#   'Haynes Old Block',
#   '94',
#   '55.0',
#   'California',
#   'Coombsville',
#   'Chardonnay',
#   'Ancien'],
#  ['577',
#   'France',
#   'Dou Barringuet',
#   '94',
#   '40.0',
#   'Southwest France',
#   'Madiran',
#   'Tannat-Cabernet',
#   'Château de Gayon'],
#  ['578',
#   'US',
#   'Cuvée Sandre',
#   '94',
#   '68.0',
#   'California',
#   'Sta. Rita Hills',
#   'Pinot Noir',
#   'Demetria'],
#  ['579',
#   'US',
#   'Two Barns Vineyard',
#   '94',
#   '90.0',
#   'Oregon',
#   'Dundee Hills',
#   'Pinot Noir',
#   'Domaine Serene'],
#  ['580',
#   'France',
#   'Seigneur de Grézette',
#   '93',
#   '25.0',
#   'Southwest France',
#   'Cahors',
#   'Malbec-Merlot',
#   'Château Lagrézette'],
#  ['581',
#   'US',
#   'Rogers Creek',
#   '93',
#   '60.0',
#   'California',
#   'Sonoma Coast',
#   'Pinot Noir',
#   'Cherry Pie'],
#  ['584',
#   'US',
#   "Oliver's Vineyard",
#   '93',
#   '85.0',
#   'California',
#   'Alexander Valley',
#   'Cabernet Sauvignon',
#   'Aperture'],
#  ['585',
#   'US',
#   "Ocean's Ghost Babcock Vineyard",
#   '93',
#   '60.0',
#   'California',
#   'Sta. Rita Hills',
#   'Pinot Noir',
#   'Babcock'],
#  ['586',
#   'Spain',
#   'Reserva Edición Especial Sergio Hernández',
#   '93',
#   '64.0',
#   'Northern Spain',
#   'Ribera del Duero',
#   'Tempranillo',
#   'Lleiroso'],
#  ['589',
#   'US',
#   'Bien Nacido Vineyard',
#   '93',
#   '55.0',
#   'California',
#   'Santa Maria Valley',
#   'Syrah',
#   'Nicora'],
#  ['591',
#   'US',
#   'Medici Vineyard',
#   '93',
#   '48.0',
#   'Oregon',
#   'Chehalem Mountains',
#   'Pinot Noir',
#   'Patricia Green Cellars'],
#  ['592',
#   'US',
#   'Story Vineyard',
#   '93',
#   '40.0',
#   'California',
#   'Amador County',
#   'Zinfandel',
#   'Renwood'],
#  ['593',
#   'US',
#   'Santa Catalina Island Vineyards',
#   '93',
#   '60.0',
#   'California',
#   'California',
#   'Chardonnay',
# ...
#   'Côtes de Provence',
#   'Rosé',
#   'Château Saint-Maur'],
#  ['1507',
#   'France',
#   'Cuvée du Couvent',
#   '92',
#   '25.0',
#   'Southwest France',
#   'Madiran',
#   'Tannat',
#   'Domaine Capmartin'],
#  ['1508',
#   'US',
#   'Côte Sud Vineyard',
#   '92',
#   '75.0',
#   'Oregon',
#   'Dundee Hills',
#   'Pinot Noir',
#   'Domaine Serene'],
#  ['1509',
#   'US',
#   'Coeur Blanc (White Heart)',
#   '92',
#   '95.0',
#   'Oregon',
#   'Willamette Valley',
#   'Pinot Noir',
#   'Domaine Serene'],
#  ['1510',
#   'US',
#   'Lock Vineyard',
#   '92',
#   '42.0',
#   'California',
#   'Paso Robles',
#   'Cabernet Sauvignon',
#   'Écluse'],
#  ['1512',
#   'US',
#   'Ventana Vineyard',
#   '92',
#   '35.0',
#   'California',
#   'Arroyo Seco',
#   'Grenache',
#   'Joyce'],
#  ['1514',
#   'US',
#   'Backbone',
#   '92',
#   '28.0',
#   'Oregon',
#   'Willamette Valley',
#   'Pinot Gris',
#   'King Estate'],
#  ['1515',
#   'US',
#   'Westlands',
#   '92',
#   '54.0',
#   'California',
#   'Sonoma Coast',
#   'Pinot Noir',
#   'Anaba'],
#  ['1517',
#   'US',
#   'E Street',
#   '92',
#   '40.0',
#   'California',
#   'Paso Robles Willow Creek District',
#   'Tempranillo',
#   'Barton'],
#  ['1518',
#   'US',
#   'Le Pré du Col Vineyard',
#   '92',
#   '68.0',
#   'Oregon',
#   'Ribbon Ridge',
#   'Pinot Noir',
#   'Bergström'],
#  ['1519',
#   'France',
#   'Excellence des Muraires',
#   '92',
#   '59.0',
#   'Provence',
#   'Côtes de Provence',
#   'Rosé',
#   'Bernard Magrez'],
#  ['1520',
#   'France',
#   'Optimum',
#   '92',
#   '28.0',
#   'Southwest France',
#   'Fronton',
#   'Red Blend',
#   'Château Bellevue la Forêt'],
#  ['1522',
#   'US',
#   'DVX Sparkling Rosé',
#   '92',
#   '80.0',
#   'California',
#   'Napa Valley',
#   'Sparkling Blend',
#   'Mumm Napa'],
#  ['1525',
#   'US',
#   'Avellana Vineyard',
#   '92',
#   '63.0',
#   'Oregon',
#   'Willamette Valley',
#   'Chardonnay',
#   'Ponzi'],
#  ['1526',
#   'US',
#   'Arsenal',
#   '92',
#   '40.0',
#   'Oregon',
#   'Applegate Valley',
#   'Cabernet Franc-Merlot',
#   'Quady North'],
#  ['1528',
#   'US',
#   'Jack Rabbit Flat Vineyard',
#   '92',
#   '50.0',
#   'California',
#   'Amador County',
#   'Zinfandel',
#   'Renwood'],
#  ['1529',
#   'US',
#   "Gino's",
#   '92',
#   '34.0',
#   'California',
#   'Dry Creek Valley',
#   'Zinfandel',
#   'Sbragia'],
#  ['1533',
#   'Italy',
#   'Bianco',
#   '85',
#   '10.0',
#   'Veneto',
#   'Veronese',
#   'White Blend',
#   'Amatore'],
#  ['1534',
#   'Italy',
#   'Flauto Magico Riserva',
#   '85',
#   '149.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Paradiso di Frassina'],
#  ['1535',
#   'US',
#   'Cesar',
#   '85',
#   '26.0',
#   'Washington',
#   'Horse Heaven Hills',
#   'Bordeaux-style Red Blend',
#   'Martinez & Martinez'],
#  ['1536',
#   'Argentina',
#   'Premium Series',
#   '85',
#   '16.0',
#   'Other',
#   'La Rioja',
#   'Torrontés',
#   'Solo Contigo'],
#  ['1538',
#   'Argentina',
#   'Clásico',
#   '84',
#   '12.0',
#   'Mendoza Province',
#   'Mendoza',
#   'Malbec',
#   'Altos Las Hormigas'],
#  ['1541',
#   'US',
#   "Bianca's White",
#   '84',
#   '15.0',
#   'California',
#   'Napa Valley',
#   'Sauvignon Blanc-Semillon',
#   'Napa by N.A.P.A.'],
#  ['1544',
#   'France',
#   'Château Noël Saint Laurent',
#   '84',
#   '14.0',
#   'Rhône Valley',
#   'Côtes du Rhône',
#   'Rhône-style White Blend',
#   'Louis Bernard'],
#  ['1545',
#   'Argentina',
#   '505 Esencia',
#   '84',
#   '12.0',
#   'Mendoza Province',
#   'Mendoza',
#   'Bordeaux-style Red Blend',
#   'Casarena'],
#  ['1546',
#   'Spain',
#   'Don Ramón',
#   '84',
#   '9.0',
#   'Northern Spain',
#   'Campo de Borja',
#   'Red Blend',
#   'Bodegas Aragonesas'],
#  ['1549',
#   'US',
#   'Verdigris',
#   '84',
#   '35.0',
#   'California',
#   'Livermore Valley',
#   'White Blend',
#   'Las Positas'],
#  ['1550',
#   'France',
#   'La Fleur Lily Semi-Sweet',
#   '84',
#   '12.0',
#   'Southwest France',
#   'Côtes de Bergerac',
#   'Bordeaux-style White Blend',
#   'Domaine de Grange Neuve'],
#  ['1552',
#   'Argentina',
#   'Ji Ji Ji Finca Villa Seca Gen Fuerza Tranquila',
#   '84',
#   '17.0',
#   'Mendoza Province',
#   'Tupungato',
#   'Chenin Blanc',
#   'Gen Del Alma'],
#  ['1557',
#   'Spain',
#   'Dulce Blanco',
#   '84',
#   '14.0',
#   'Levante',
#   'Jumilla',
#   'Macabeo',
#   'Casa de la Ermita'],
#  ['1560',
#   'US',
#   'Gamma: The Complex',
#   '92',
#   '35.0',
#   'California',
#   'Sta. Rita Hills',
#   'Syrah',
#   'Ampelos'],
#  ['1561',
#   'US',
#   'Dijon Clone',
#   '92',
#   '32.0',
#   'Washington',
#   'Yakima Valley',
#   'Chardonnay',
#   'Array'],
#  ['1562',
#   'US',
#   'Seventeen Forty Reserve',
#   '92',
#   '56.0',
#   'California',
#   'Paso Robles',
#   'Bordeaux-style Red Blend',
#   'Daou'],
#  ['1563',
#   'US',
#   'Ciel du Cheval Vineyard',
#   '92',
#   '39.0',
#   'Washington',
#   'Red Mountain',
#   'Merlot',
#   'Côtes de Ciel'],
#  ['1565',
#   'US',
#   'Upland Vineyards',
#   '92',
#   '40.0',
#   'Washington',
#   'Snipes Mountain',
#   'Syrah',
#   'Kerloo'],
#  ['1566',
#   'US',
#   'Zabala Vineyard',
#   '92',
#   '20.0',
#   'California',
#   'Arroyo Seco',
#   'Sauvignon Blanc',
#   'Mercy'],
#  ['1570',
#   'US',
#   'Mesa Reserve Estate Grown and Bottled',
#   '92',
#   '48.0',
#   'California',
#   'Santa Ynez Valley',
#   'Syrah',
#   'Zaca Mesa'],
#  ['1571',
#   'France',
#   'Vieilles Vignes',
#   '91',
#   '14.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Domaine Jean Sipp'],
#  ['1573',
#   'France',
#   'Kessler Grand Cru',
#   '91',
#   '38.0',
#   'Alsace',
#   'Alsace',
#   'Gewürztraminer',
#   'Domaines Schlumberger'],
#  ['1575',
#   'US',
#   'Cuvée Sauvage',
#   '91',
#   '40.0',
#   'California',
#   'Carneros',
#   'Chardonnay',
#   'Franciscan'],
#  ['1577',
#   'US',
#   'Rolleri Cuvée',
#   '91',
#   '26.0',
#   'California',
#   'Calaveras County',
#   'Tempranillo',
#   'Hovey'],
#  ['1579',
#   'US',
#   'Estate',
#   '91',
#   '30.0',
#   'California',
#   'Sierra Foothills',
#   'Syrah',
#   'Martin Lane Winery'],
#  ['1582',
#   'France',
#   'Castelnau de Suduiraut',
#   '91',
#   '35.0',
#   'Bordeaux',
#   'Sauternes',
#   'Bordeaux-style White Blend',
#   'Château Suduiraut'],
#  ['1587',
#   'US',
#   'Estate',
#   '91',
#   '15.0',
#   'California',
#   'Paso Robles',
#   'Chardonnay',
#   'Castoro Cellars'],
#  ['1589',
#   'France',
#   'Seppi Landmann Zinnkoeplé Grand Cru',
#   '91',
#   '36.0',
#   'Alsace',
#   'Alsace',
#   'Riesling',
#   'Domaine Rieflé-Landmann'],
#  ['1590',
#   'US',
#   'The Reserve',
#   '87',
#   '25.0',
#   'Washington',
#   'Horse Heaven Hills',
#   'Chardonnay',
#   '14 Hands'],
#  ['1591',
#   'US',
#   'The Reserve',
#   '87',
#   '22.0',
#   'Washington',
#   'Horse Heaven Hills',
#   'Sauvignon Blanc',
#   '14 Hands'],
#  ['1592',
#   'US',
#   'Old Vine',
#   '87',
#   '25.0',
#   'California',
#   'Lodi',
#   'Zinfandel',
#   'Boneshaker'],
#  ['1593',
#   'US',
#   'MV Trí3',
#   '87',
#   '32.0',
#   'Washington',
#   'Columbia Valley (WA)',
#   'Rhône-style Red Blend',
#   'Cairdeas'],
#  ['1595',
#   'US',
#   'Reserve',
#   '87',
#   '35.0',
#   'California',
#   'Edna Valley',
#   'Chardonnay',
#   'Edna Valley Vineyard'],
#  ['1596',
#   'Argentina',
#   'Reserve',
#   '87',
#   '18.0',
#   'Mendoza Province',
#   'Mendoza',
#   'Malbec',
#   'Ferllen'],
#  ['1598',
#   'Italy',
#   'Riserva',
#   '87',
#   '140.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Tenuta di Sesta'],
#  ['1599',
#   'Italy',
#   'Due Sorelle Riserva',
#   '87',
#   '60.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Tenuta La Fuga'],
#  ['1600',
#   'Italy',
#   'Emilio Primo',
#   '87',
#   '25.0',
#   'Tuscany',
#   'Bolgheri',
#   'Red Blend',
#   'Terre del Marchesato'],
#  ['1602',
#   'Italy',
#   'Ripe al Convento Riserva',
#   '87',
#   '138.0',
#   'Tuscany',
#   'Brunello di Montalcino',
#   'Sangiovese',
#   'Castelgiocondo'],
#  ['1606',
#   'US',
#   'Cutthroat Blend',
#   '87',
#   '35.0',
#   'Washington',
#   'Columbia Valley (WA)',
#   'Red Blend',
#   'Flying Trout'],
#  ['1607',
#   'US',
#   'Mélange Blanc',
#   '87',
#   '23.0',
#   'Washington',
#   'Columbia Valley (WA)',
#   'White Blend',
#   'Patterson'],
#  ['1608',
#   'France',
#   'Château Courbian',
#   '87',
#   '19.0',
#   'Bordeaux',
#   'Médoc',
#   'Bordeaux-style Red Blend',
#   'Producta Vignobles'],
#  ['1610',
#   'US',
#   'Sofia Blanc de Blancs',
#   '87',
#   '19.0',
#   'California',
#   'Monterey County',
#   'Sparkling Blend',
#   'Francis Ford Coppola'],
#  ['1612',
#   'US',
#   'Springline Super Tuscan-style',
#   '87',
#   '19.0',
#   'Washington',
#   'Columbia Valley (WA)',
#   'White Blend',
#   'Genoa'],
#  ['1613',
#   'US',
#   'Bacigalupi Vineyard',
#   '87',
#   '48.0',
#   'California',
#   'Russian River Valley',
#   'Zinfandel',
#   'Graton Ridge'],
#  ['1614',
#   'US',
#   'Estate Bottled',
#   '87',
#   '20.0',
#   'California',
#   'Anderson Valley',
#   'Gewürztraminer',
#   'Navarro'],
#  ['1615',
#   'US',
#   'Sharp Sisters',
#   '87',
#   '26.0',
#   'Washington',
#   'Columbia Valley (WA)',
#   'Red Blend',
#   'Mercer'],
#  ['1617',
#   'US',
#   'Estate Grown',
#   '87',
#   '60.0',
#   'Washington',
#   'Columbia Gorge (WA)',
#   'Syrah',
#   'Syncline'],
#  ['1618',
#   'US',
#   'Boushey Vineyard',
#   '87',
#   '25.0',
#   'Washington',
#   'Yakima Valley',
#   'Grenache Blanc',
#   'Syncline'],
#  ['1620',
#   'France',
#   'Brut Prestige',
#   '91',
#   '66.0',
#   'Champagne',
#   'Champagne',
#   'Champagne Blend',
#   'Charles Ellner'],
#  ['1622',
#   'France',
#   'Brut Nature',
#   '91',
#   '75.0',
#   'Champagne',
#   'Champagne',
#   'Champagne Blend',
#   'Ayala'],
#  ['1623',
#   'Italy',
#   'Riserva',
#   '90',
#   '25.0',
#   'Tuscany',
#   'Chianti Classico',
#   'Red Blend',
#   'Fattoria La Ripa'],
#  ['1624',
#   'US',
#   'Special Reserve',
#   '90',
#   '40.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Herzog'],
#  ['1625',
#   'US',
#   'Estate Grown Cave Fermented',
#   '90',
#   '95.0',
#   'California',
#   'Napa Valley',
#   'Merlot',
#   'Jarvis'],
#  ['1626',
#   'US',
#   'Sierra Madre Vineyard',
#   '90',
#   '48.0',
#   'California',
#   'Santa Barbara County',
#   'Pinot Noir',
#   'La Montagne'],
#  ['1627',
#   'US',
#   'Lachini Family Estate',
#   '90',
#   '48.0',
#   'Oregon',
#   'Chehalem Mountains',
#   'Pinot Noir',
#   'Lachini'],
#  ['1628',
#   'US',
#   'Serious',
#   '90',
#   '50.0',
#   'California',
#   'Lodi',
#   'Zinfandel',
#   'Macchia'],
#  ['1629',
#   'US',
#   'Estate 25th Anniversary',
#   '90',
#   '28.0',
#   'California',
#   'Santa Lucia Highlands',
#   'Chardonnay',
#   'McIntyre Vineyards'],
#  ['1631',
#   'US',
#   'Reed Vineyard',
#   '90',
#   '60.0',
#   'California',
#   'Mt. Harlan',
#   'Pinot Noir',
#   'Calera'],
#  ['1633',
#   'France',
#   'Grande Réserve Brut',
#   '90',
#   '50.0',
#   'Champagne',
#   'Champagne',
#   'Champagne Blend',
#   'Charles Ellner'],
#  ['1634',
#   'France',
#   'La Chêneraie',
#   '90',
#   '55.0',
#   'Bordeaux',
#   'Fronsac',
#   'Bordeaux-style Red Blend',
#   'Château Jeandeman'],
#  ['1638',
#   'Italy',
#   'Limne',
#   '90',
#   '19.0',
#   'Lombardy',
#   'Lugana',
#   'Turbiana',
#   'Tenuta Roveglia'],
#  ['1639',
#   'US',
#   'Reserve',
#   '90',
#   '50.0',
#   'California',
#   'Napa Valley',
#   'Cabernet Sauvignon',
#   'Triumph Cellars'],
#  ['1642',
#   'US',
#   'Dark & Brooding',
#   '90',
#   '54.0',
#   'California',
#   'Sonoma County',
#   'Red Blend',
#   'Palmeri'],
#  ['1644',
#   'US',
#   'Pendulum',
#   '90',
#   '35.0',
#   'California',
#   'Monterey County',
#   'Rhône-style Red Blend',
#   'Baker & Brain'],
#  ['1645',
#   'US',
#   'Bald Mountain Vineyard',
#   '90',
#   '45.0',
#   'California',
#   'Ben Lomond Mountain',
#   'Chardonnay',
#   'Beauregard'],
#  ['1650',
#   'US',
#   'The Augur Kick On Ranch Vineyard',
#   '88',
#   '25.0',
#   'California',
#   'Santa Barbara County',
#   'Riesling',
#   'j.brix'],
#  ['1651',
#   'US',
#   '1149 Rosé of',
#   '88',
#   '25.0',
#   'California',
#   'Paso Robles Willow Creek District',
#   'Mourvèdre',
#   'Jada Vineyard & Winery'],
#  ['1653',
#   'US',
#   'Brut Rosé',
#   '88',
#   '30.0',
#   'California',
#   'Arroyo Grande Valley',
#   'Sparkling Blend',
#   'Laetitia'],
#  ['1654',
#   'US',
#   'Rayhill Vineyard',
#   '88',
#   '60.0',
#   'California',
#   'Sonoma Coast',
#   'Pinot Noir',
#   'Landmark'],
#  ['1656',
#   'Italy',
#   'Quercegobbe',
#   '88',
#   '65.0',
#   'Tuscany',
#   'Toscana',
#   'Merlot',
#   'Petra'],
#  ['1657',
#   'Italy',
#   'Maurleo',
#   '88',
#   '19.0',
#   'Tuscany',
#   'Toscana',
#   'Red Blend',
#   'Pietro Beconcini'],
#  ['1658',
#   'Italy',
#   'Lippo',
#   '88',
#   '28.0',
#   'Tuscany',
#   'Toscana',
#   'Red Blend',
#   'Pieve Santo Stefano'],
#  ['1661',
#   'US',
#   'Dianthus',
#   '88',
#   '27.0',
#   'California',
#   'Paso Robles',
#   'Rosé',
#   'Tablas Creek'],
#  ['1662',
#   'Italy',
#   'Trasolo',
#   '88',
#   '120.0',
#   'Tuscany',
#   'Toscana',
#   'Merlot',
#   'Tenuta Villa Trasqua'],
#  ['1664',
#   'France',
#   "Baron d'Ardeuil Vieilles Vignes",
#   '88',
#   '15.0',
#   'Southwest France',
#   'Buzet',
#   'Bordeaux-style Red Blend',
#   'Vignerons de Buzet'],
#  ['1666',
#   'US',
#   'Reserve',
#   '88',
#   '35.0',
#   'California',
#   'Santa Cruz Mountains',
#   'Chardonnay',
#   'Wrights Station'],
#  ['1668',
#   'France',
#   'Cuvée des Conti',
#   '88',
#   '16.0',
#   'Southwest France',
#   'Bergerac Sec',
#   'Bordeaux-style White Blend',
#   'Château Tour des Gendres'],
#  ['1669',
#   'France',
#   'Château Bazin',
#   '88',
#   '45.0',
#   'Southwest France',
#   'Côtes du Marmandais',
#   'Red Blend',
#   'Cave du Marmandais'],
#  ['1670',
#   'Italy',
#   'Serisè',
#   '88',
#   '22.0',
#   'Tuscany',
#   'Toscana',
#   'Ciliegiolo',
#   'Cesani'],
#  ['1673',
#   'Italy',
#   'Poggio ai Merli',
#   '88',
#   '110.0',
#   'Tuscany',
#   'Toscana',
#   'Merlot',
#   'Castellare di Castellina'],
#  ['1674',
#   'Italy',
#   'Non Confonditur',
#   '88',
#   '26.0',
#   'Tuscany',
#   'Toscana',
#   'Red Blend',
#   'Argiano'],
#  ['1675',
#   'US',
#   'Hope',
#   '88',
#   '40.0',
#   'California',
#   'California',
#   'Red Blend',
#   'Aver Family Vineyards'],
#  ['1677',
#   'US',
#   'The Sheriff',
#   '88',
#   '36.0',
#   'California',
#   'Livermore Valley',
#   'Rhône-style Red Blend',
#   'Vasco Urbano'],
#  ['1679',
#   'Spain',
#   'Castillo de Albai Crianza',
#   '88',
#   '15.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo',
#   'Pagos del Rey'],
#  ['1682',
#   'US',
#   'Alloro Vineyard',
#   '88',
#   '60.0',
#   'Oregon',
#   'Chehalem Mountains',
#   'Pinot Noir',
#   'Torii Mor'],
#  ['1684',
#   'US',
#   'Upstream',
#   '88',
#   '25.0',
#   'California',
#   'Lodi',
#   'Zinfandel',
#   'Watts'],
#  ['1690',
#   'US',
#   'York Creek Vineyard',
#   '88',
#   '37.0',
#   'California',
#   'Napa Valley',
#   'Petite Sirah',
#   'Elyse'],
#  ['1692',
#   'US',
#   'Preston Vineyards',
#   '88',
#   '25.0',
#   'California',
#   'Dry Creek Valley',
#   'Sauvignon Blanc',
#   'Horse & Plow'],
#  ['1693',
#   'US',
#   'Le Cigare Blanc Beeswax Vineyard',
#   '88',
#   '26.0',
#   'California',
#   'Arroyo Seco',
#   'Rhône-style White Blend',
#   'Bonny Doon'],
#  ['1698',
#   'US',
#   'Estate',
#   '88',
#   '10.0',
#   'California',
#   'Amador County',
#   'Sauvignon Blanc',
#   'Clos du Lac'],
#  ['1700',
#   'US',
#   'Sexton Hill Vineyard',
#   '88',
#   '42.0',
#   'California',
#   'Russian River Valley',
#   'Pinot Noir',
#   'Balletto'],
#  ['1704',
#   'Spain',
#   'Maceración Carbónica',
#   '88',
#   '16.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo Blend',
#   'Dominio de Berzal'],
#  ['1705',
#   'Spain',
#   "AV14 Clos d'Englora",
#   '88',
#   '30.0',
#   'Catalonia',
#   'Montsant',
#   'Red Blend',
#   'Cellers Baronia del Montsant'],
#  ['1706',
#   'Spain',
#   'Inspiración Las Canteras',
#   '88',
#   '25.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo Blend',
#   'Bodegas Valdemar'],
#  ['1707',
#   'Spain',
#   'Crianza',
#   '88',
#   '15.0',
#   'Northern Spain',
#   'Rioja',
#   'Tempranillo Blend',
#   'Viña Herminia'],
#  ['1710',
#   'US',
#   'DuPratt Vineyard Old Vine',
#   '90',
#   '24.0',
#   'California',
#   'Mendocino Ridge',
#   'Zinfandel',
#   'Steele'],
#  ['1713',
#   'France',
#   'Maison du Villard',
#   '90',
#   '35.0',
#   'Burgundy',
#   'Pouilly-Fuissé',
#   'Chardonnay',
#   'Château de Lavernette'],
#  ['1714',
#   'US',
#   'Estate Bottled',
#   '90',
#   '18.0',
#   'California',
#   'El Dorado',
#   'Sauvignon Blanc',
#   'Lava Cap'],
#  ['1716',
#   'US',
#   'Estate Bottled',
#   '90',
#   '35.0',
#   'California',
#   'Shenandoah Valley (CA)',
#   'Zinfandel',
#   'Easton'],
#  ['1717',
#   'US',
#   'Reserve',
#   '90',
#   '35.0',
#   'California',
#   'Edna Valley',
#   'Chardonnay',
#   'Edna Valley Vineyard'],
#  ['1719',
#   'US',
#   'Erato De Portola Trail Vineyard',
#   '90',
#   '45.0',
#   'California',
#   'Temecula Valley',
#   'Cabernet Franc',
#   'Gershon Bachus'],
#  ['1720',
#   'US',
#   'El Jabali Vineyard Brut Rosé',
#   '90',
#   '65.0',
#   'California',
#   'Sta. Rita Hills',
#   'Sparkling Blend',
#   'Alma Rosa'],
#  ['1721',
#   'US',
#   'Collins Holystone Vineyard Old Vine',
#   '90',
#   '35.0',
#   'California',
#   'St. Helena',
#   'Zinfandel',
#   'Benessere'],
#  ['1722',
#   'US',
#   'Makena',
#   '90',
#   '35.0',
#   'Oregon',
#   'Eola-Amity Hills',
#   'Pinot Noir',
#   'BKB'],
#  ['1723',
#   'US',
#   'Mortal Zin',
#   '90',
#   '38.0',
#   'California',
#   'Paso Robles',
#   'Zinfandel',
#   'Graveyard'],
#  ['1724',
#   'US',
#   'Aatto',
#   '90',
#   '40.0',
#   'California',
#   'Adelaida District',
#   'Rhône-style Red Blend',
#   'kukkula'],
#  ...]

# %%
wine_data[0]
# Out:
# ['ID',
#  'country',
#  'designation',
#  'points',
#  'price',
#  'province',
#  'region',
#  'variety',
#  'winery']

# %%
wine_data[1]
# Out:
# ['0',
#  'US',
#  "Martha's Vineyard",
#  '96',
#  '235.0',
#  'California',
#  'Napa Valley',
#  'Cabernet Sauvignon',
#  'Heitz']

# %% [markdown]
# ### Example Filter
#
# Separate all _A+_ wines from _Oregon_ (assuming _A+_ means more than $95$ points):

# %%
# Initialize variable based on what we want the result to be
# In this case, a list of wines
good_or = []

# skip header
for wine in wine_data[1:]:
  if wine[5] == "Oregon" and float(wine[3]) > 95:
    good_or.append(wine)

print(len(good_or))
print(good_or)
# Out:
# 7
# [['3', 'US', 'Reserve', '96', '65.0', 'Oregon', 'Willamette Valley', 'Pinot Noir', 'Ponzi'], ['2441', 'US', 'Estate Justina', '96', '85.0', 'Oregon', 'Chehalem Mountains', 'Pinot Noir', 'Alloro'], ['2445', 'US', 'Abbott Claim Vineyard', '96', '63.0', 'Oregon', 'Willamette Valley', 'Pinot Noir', 'Ken Wright'], ['2455', 'US', 'Bryce Vineyard', '96', '63.0', 'Oregon', 'Ribbon Ridge', 'Pinot Noir', 'Ken Wright'], ['6007', 'US', 'Original Vines Estate', '96', '85.0', 'Oregon', 'Dundee Hills', 'Pinot Noir', 'The Eyrie Vineyards'], ['6010', 'US', 'Édition Limitée', '96', '85.0', 'Oregon', 'Dundee Hills', 'Pinot Noir', 'Domaine Drouhin Oregon'], ['10597', 'US', 'Latifeh', '96', '100.0', 'Oregon', 'Willamette Valley', 'Pinot Noir', 'Ayoub']]

# %%
# total price of all California wines 

total_price = 0

for wine in wine_data[1:]:
  if wine[5] == "California":
    total_price = total_price + float(wine[4])

print(total_price)
# Out:
# 115510.0

# %%
# Find least expensive wine from CA

min_price = float("inf")
# So we start with the largest possible value, then look for smaller ones.
cheapest_wine = None
# none - because at the beginning of the program we have not found any wine yet

for wine in wine_data[1:]:
    if wine[5] == "California":
        price = float(wine[4])

        if price < min_price:
            min_price = price
            cheapest_wine = wine

print("Cheapest CA wine price:", min_price)
print("Wine:", cheapest_wine)
# Out:
# Cheapest CA wine price: 4.0
# Wine: ['1858', 'US', 'Unoaked', '83', '4.0', 'California', 'California', 'Chardonnay', "Pam's Cuties"]

# %%
# Find the most expensive wine from CA

max_price = 0
# When finding the maximum, you must start with a very small value, therefore 0
# max_price = float("inf") - Nothing is greater than infinity, so the condition never becomes True.
most_expensive_wine = None
# none - because at the beginning of the program we have not found any wine yet

for wine in wine_data [1:]:
   if wine[5] == "California":
      price = float(wine[4])
#Take the price from the dataset and convert it into a number so we can compare it.

      if price > max_price:
         max_price = price
         most_expensive_wine = wine

print ("Most expencive CA wine price", max_price)
print ("Wine:", most_expensive_wine)
# Out:
# Most expencive CA wine price 2013.0
# Wine: ['13318', 'US', 'Roger Rose Vineyard', '91', '2013.0', 'California', 'Arroyo Seco', 'Chardonnay', 'Blair']

# %%
# Find the most expensive wine from the list

expencive_wine = wine_data[1]
# Assume the first wine in the dataset is the most expensive for now

#Go through every wine in the dataset. [1:] skips the header row.
for wine in wine_data[1:]:
#if the current wine price is greater than the saved expensive wine price.
  if float(wine[4]) > float(expencive_wine[4]):
   #The current wine is more expensive, so save it as the new most expensive wine.
    expencive_wine = wine


print(expencive_wine)
# Out:
# ['13318', 'US', 'Roger Rose Vineyard', '91', '2013.0', 'California', 'Arroyo Seco', 'Chardonnay', 'Blair']

# %%
# Find the most expensive wine from Spain

# 1.Start with a starting value
max_price = 0
most_expensive_wine = None

# 2. Look at every wine
for wine in wine_data [1:]:

# 3. Filter the wines you care about
  if wine[1] == "Spain":
# 4. Compare the price
      price = float(wine[4])
      # Is this wine more expensive than the current best one?

  if price > max_price:
         max_price = price
         most_expensive_wine = wine

print ("Most expencive Spain wine price", max_price)
print ("Wine:", most_expensive_wine)

#scan wines → keep only Spain → compare prices → remember biggest
# Out:
# Most expencive Spain wine price 770.0
# Wine: ['2453', 'Spain', 'El Perer', '96', '770.0', 'Catalonia', 'Priorat', 'Carignan', 'Marco Abella']

# %%
#What’s the average rating for California wines?

total_points = 0 # we do not know the total points, therefore 0
count = 0 #we do not know the total California wines there are

for wine in wine_data[1:]:
    if wine[5] == "California":
        total_points = total_points + float(wine[3])
        count = count + 1

average = total_points / count

print("Average rating for California wines:", average)
# Out:
# Average rating for California wines: 89.51834862385321

# %%
# are the best wine the also the most expencive?
# Do wines with the highest ratings (points) also always have the highest prices

cheap_good_wines = []

for wine in wine_data[1:]:
    points = float(wine[3])
    price = float(wine[4])

    if points > 92 and price < 20:
        cheap_good_wines.append(wine)

print("Number of cheap high-rated wines:", len(cheap_good_wines))
print(cheap_good_wines[:10])
# Out:
# Number of cheap high-rated wines: 0
# []

# %% [markdown]
# ## Which country between spain/us/france has highest average price ?

# %%
wine_data[10:]

# %%
wine_data[0]

# %%
# TODO: separate prices into 3 lists, one for each country
# TODO: calculate the average (sum / length)

wines_sp = []
wines_us = []

for wine in wine_data[1:]:
  if wine[1] == "Spain":
    wines_sp.append(wine)
  if wine[1] == "US":
    wines_us.append(wine)

display(len(wines_sp))

sum_sp = 0
for wine in wines_sp:
  sum_sp = sum_sp + float(wine[4])

sum_sp / len(wines_sp)
# Out:
# 696
# 36.827586206896555

# %%
def filter_by_country(all_data, which_country):
  filtered_items = []

  for item in all_data:
    if item[1] == which_country:
      filtered_items.append(item)

  return filtered_items

# %%
wines_us = filter_by_country(wine_data[1:], "US")
wines_sp = filter_by_country(wine_data[1:], "Spain")

display(len(wines_us))
display(len(wines_sp))

# %%
sum_sp = 0
cnt_sp = 0

for wine in wine_data[1:]:
  if wine[1] == "Spain":
    sum_sp = sum_sp + float(wine[4])
    cnt_sp = cnt_sp + 1

display(sum_sp)
display(sum_sp / cnt_sp)

# %%
prices_sp = []

for wine in wine_data[1:]:
  if wine[1] == "Spain":
    prices_sp.append(float(wine[4]))

sum(prices_sp) / len(prices_sp)
